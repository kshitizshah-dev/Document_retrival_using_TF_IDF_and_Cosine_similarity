# %%
import os
import re
import numpy as np
import pandas as pd
import math

# %%
def open_file(directory):
  documents = []
  for filenames in os.listdir(directory):
    if filenames.endswith(".txt"):
      with open(os.path.join(directory, filenames), 'r') as f:
        documents.append(f.read())
  return documents

# %%
doc_files = open_file('/content/ebooks')

# %%
doc_files
# Out:
# ['\ufeffThe Project Gutenberg eBook of The Adventures of Tom Sawyer, Complete\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: The Adventures of Tom Sawyer, Complete\n\nAuthor: Mark Twain\n\nRelease date: July 1, 2004 [eBook #74]\n                Most recently updated: August 9, 2023\n\nLanguage: English\n\nCredits: David Widger\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK THE ADVENTURES OF TOM SAWYER, COMPLETE ***\n\n\n\n\nTHE ADVENTURES OF TOM SAWYER\n\n\nBy Mark Twain\n\n(Samuel Langhorne Clemens)\n\n\n\n\nCONTENTS\n\n\nCHAPTER I. Y-o-u-u Tom—Aunt Polly Decides Upon her Duty—Tom Practices\nMusic—The Challenge—A Private Entrance\n\nCHAPTER II. Strong Temptations—Strategic Movements—The Innocents\nBeguiled\n\nCHAPTER III. Tom as a General—Triumph and Reward—Dismal\nFelicity—Commission and Omission\n\nCHAPTER IV. Mental Acrobatics—Attending Sunday—School—The\nSuperintendent—“Showing off”—Tom Lionized\n\nCHAPTER V. A Useful Minister—In Church—The Climax\n\nCHAPTER VI. Self-Examination—Dentistry—The Midnight Charm—Witches and\nDevils—Cautious Approaches—Happy Hours\n\nCHAPTER VII. A Treaty Entered Into—Early Lessons—A Mistake Made\n\nCHAPTER VIII. Tom Decides on his Course—Old Scenes Re-enacted\n\nCHAPTER IX. A Solemn Situation—Grave Subjects Introduced—Injun Joe\nExplains\n\nCHAPTER X. The Solemn Oath—Terror Brings Repentance—Mental Punishment\n\nCHAPTER XI. Muff Potter Comes Himself—Tom’s Conscience at Work\n\nCHAPTER XII. Tom Shows his Generosity—Aunt Polly Weakens\n\nCHAPTER XIII. The Young Pirates—Going to the Rendezvous—The Camp—Fire\nTalk\n\nCHAPTER XIV. Camp-Life—A Sensation—Tom Steals Away from Camp\n\nCHAPTER XV. Tom Reconnoiters—Learns the Situation—Reports at Camp\n\nCHAPTER XVI. A Day’s Amusements—Tom Reveals a Secret—The Pirates take a\nLesson—A Night Surprise—An Indian War\n\nCHAPTER XVII. Memories of the Lost Heroes—The Point in Tom’s Secret\n\nCHAPTER XVIII. Tom’s Feelings Investigated—Wonderful Dream—Becky\nThatcher Overshadowed—Tom Becomes Jealous—Black Revenge\n\nCHAPTER XIX. Tom Tells the Truth\n\nCHAPTER XX. Becky in a Dilemma—Tom’s Nobility Asserts Itself\n\nCHAPTER XXI. Youthful Eloquence—Compositions by the Young Ladies—A\nLengthy Vision—The Boy’s Vengeance Satisfied\n\nCHAPTER XXII. Tom’s Confidence Betrayed—Expects Signal Punishment\n\nCHAPTER XXIII. Old Muff’s Friends—Muff Potter in Court—Muff Potter\nSaved\n\nCHAPTER XXIV. Tom as the Village Hero—Days of Splendor and Nights of\nHorror—Pursuit of Injun Joe\n\nCHAPTER XXV. About Kings and Diamonds—Search for the Treasure—Dead\nPeople and Ghosts\n\nCHAPTER XXVI. The Haunted House—Sleepy Ghosts—A Box of Gold—Bitter Luck\n\nCHAPTER XXVII. Doubts to be Settled—The Young Detectives\n\nCHAPTER XXVIII. An Attempt at No. Two—Huck Mounts Guard\n\nCHAPTER XXIX. The Pic-nic—Huck on Injun Joe’s Track—The “Revenge”\n Job—Aid for the Widow\n\nCHAPTER XXX. The Welshman Reports—Huck Under Fire—The Story Circulated\n—A New Sensation—Hope Giving Way to Despair\n\nCHAPTER XXXI. An Exploring Expedition—Trouble Commences—Lost in the\nCave—Total Darkness—Found but not Saved\n\nCHAPTER XXXII. Tom tells the Story of their Escape—Tom’s Enemy in Safe\nQuarters\n\nCHAPTER XXXIII. The Fate of Injun Joe—Huck and Tom Compare Notes\n—An Expedition to the Cave—Protection Against Ghosts—“An Awful Snug\nPlace”—A Reception at the Widow Douglas’s\n\nCHAPTER XXXIV. Springing a Secret—Mr. Jones’ Surprise a Failure\n\nCHAPTER XXXV. A New Order of Things—Poor Huck—New Adventures Planned\n\n\n\n\nILLUSTRATIONS\n\n\nTom Sawyer\n\nTom at Home\n\nAunt Polly Beguiled\n\nA Good Opportuni ...
#  '\ufeffThe Project Gutenberg eBook of The Yellow Wallpaper\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: The Yellow Wallpaper\n\nAuthor: Charlotte Perkins Gilman\n\nRelease date: November 1, 1999 [eBook #1952]\n                Most recently updated: August 31, 2024\n\nLanguage: English\n\nCredits: An Anonymous Volunteer and David Widger\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK THE YELLOW WALLPAPER ***\n\n\n\n\nThe Yellow Wallpaper\n\nBy Charlotte Perkins Gilman\n\n\nIt is very seldom that mere ordinary people like John and myself secure\nancestral halls for the summer.\n\nA colonial mansion, a hereditary estate, I would say a haunted house,\nand reach the height of romantic felicity—but that would be asking too\nmuch of fate!\n\nStill I will proudly declare that there is something queer about it.\n\nElse, why should it be let so cheaply? And why have stood so long\nuntenanted?\n\nJohn laughs at me, of course, but one expects that in marriage.\n\nJohn is practical in the extreme. He has no patience with faith, an\nintense horror of superstition, and he scoffs openly at any talk of\nthings not to be felt and seen and put down in figures.\n\nJohn is a physician, and perhaps—(I would not say it to a living soul,\nof course, but this is dead paper and a great relief to my\nmind)—perhaps that is one reason I do not get well faster.\n\nYou see, he does not believe I am sick!\n\nAnd what can one do?\n\nIf a physician of high standing, and one’s own husband, assures friends\nand relatives that there is really nothing the matter with one but\ntemporary nervous depression—a slight hysterical tendency—what is one\nto do?\n\nMy brother is also a physician, and also of high standing, and he says\nthe same thing.\n\nSo I take phosphates or phosphites—whichever it is, and tonics, and\njourneys, and air, and exercise, and am absolutely forbidden to “work”\nuntil I am well again.\n\nPersonally, I disagree with their ideas.\n\nPersonally, I believe that congenial work, with excitement and change,\nwould do me good.\n\nBut what is one to do?\n\nI did write for a while in spite of them; but it does exhaust me a good\ndeal—having to be so sly about it, or else meet with heavy opposition.\n\nI sometimes fancy that in my condition if I had less opposition and\nmore society and stimulus—but John says the very worst thing I can do\nis to think about my condition, and I confess it always makes me feel\nbad.\n\nSo I will let it alone and talk about the house.\n\nThe most beautiful place! It is quite alone, standing well back from\nthe road, quite three miles from the village. It makes me think of\nEnglish places that you read about, for there are hedges and walls and\ngates that lock, and lots of separate little houses for the gardeners\nand people.\n\nThere is a delicious garden! I never saw such a garden—large and shady,\nfull of box-bordered paths, and lined with long grape-covered arbors\nwith seats under them.\n\nThere were greenhouses, too, but they are all broken now.\n\nThere was some legal trouble, I believe, something about the heirs and\nco-heirs; anyhow, the place has been empty for years.\n\nThat spoils my ghostliness, I am afraid; but I don’t care—there is\nsomething strange about the house—I can feel it.\n\nI even said so to John one moonlight evening, but he said what I felt\nwas a draught, and shut the window.\n\nI get unreasonably angry with John sometimes. I’m sure I never used to\nbe so sensitive. I think it is due to this nervous condition.\n\nBut John says if I feel so I shall neglect proper self-control; so I\ntak ...
#  '\ufeffThe Project Gutenberg eBook of A Christmas Carol\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: A Christmas Carol\n\nAuthor: Charles Dickens\n\nIllustrator: Arthur Rackham\n\nRelease date: December 24, 2007 [eBook #24022]\n\nLanguage: English\n\nOriginal publication: Philadelphia and New York: J. B. Lippincott Company,, 1915\n\nCredits: Produced by Suzanne Shell, Janet Blenkinship and the Online\n        Distributed Proofreading Team at http://www.pgdp.net\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK A CHRISTMAS CAROL ***\n\n\n\n\nProduced by Suzanne Shell, Janet Blenkinship and the Online\nDistributed Proofreading Team at http://www.pgdp.net\n\n\n\n\n\n\n\n\n\n\n\n  A CHRISTMAS CAROL\n\n  [Illustration: _"How now?" said Scrooge, caustic and cold as ever.\n  "What do you want with me?"_]\n\n\n  A CHRISTMAS CAROL\n\n  [Illustration]\n\n  BY\n\n  CHARLES DICKENS\n\n  [Illustration]\n\n  ILLUSTRATED BY ARTHUR RACKHAM\n\n  [Illustration]\n\n  J. B. LIPPINCOTT COMPANY PHILADELPHIA AND NEW YORK\n\n  FIRST PUBLISHED 1915\n\n  REPRINTED 1923, 1927, 1932, 1933, 1934, 1935, 1947, 1948, 1952, 1958,\n  1962, 1964, 1966, 1967, 1969, 1971, 1972, 1973\n\n  ISBN: 0-397-00033-2\n\n  PRINTED IN GREAT BRITAIN\n\n\n\n\n  PREFACE\n\n  I have endeavoured in this Ghostly little book to raise the Ghost of an\n  Idea which shall not put my readers out of humour with themselves, with\n  each other, with the season, or with me. May it haunt their house\n  pleasantly, and no one wish to lay it.\n\n  Their faithful Friend and Servant,\n\n  C. D.\n\n  _December, 1843._\n\n\n\n\n  CHARACTERS\n\n  Bob Cratchit, clerk to Ebenezer Scrooge.\n  Peter Cratchit, a son of the preceding.\n  Tim Cratchit ("Tiny Tim"), a cripple, youngest son of Bob Cratchit.\n  Mr. Fezziwig, a kind-hearted, jovial old merchant.\n  Fred, Scrooge\'s nephew.\n  Ghost of Christmas Past, a phantom showing things past.\n  Ghost of Christmas Present, a spirit of a kind, generous,\n    and hearty nature.\n  Ghost of Christmas Yet to Come, an apparition showing the shadows\n    of things which yet may happen.\n  Ghost of Jacob Marley, a spectre of Scrooge\'s former partner in business.\n  Joe, a marine-store dealer and receiver of stolen goods.\n  Ebenezer Scrooge, a grasping, covetous old man, the surviving partner\n    of the firm of Scrooge and Marley.\n  Mr. Topper, a bachelor.\n  Dick Wilkins, a fellow apprentice of Scrooge\'s.\n\n  Belle, a comely matron, an old sweetheart of Scrooge\'s.\n  Caroline, wife of one of Scrooge\'s debtors.\n  Mrs. Cratchit, wife of Bob Cratchit.\n  Belinda and Martha Cratchit, daughters of the preceding.\n\n  Mrs. Dilber, a laundress.\n  Fan, the sister of Scrooge.\n  Mrs. Fezziwig, the worthy partner of Mr. Fezziwig.\n\n\n\n\n  CONTENTS\n\n  STAVE ONE--MARLEY\'S GHOST                                             3\n  STAVE TWO--THE FIRST OF THE THREE SPIRITS                            37\n  STAVE THREE--THE SECOND OF THE THREE SPIRITS                         69\n  STAVE FOUR--THE LAST OF THE SPIRITS                                 111\n  STAVE FIVE--THE END OF IT                                           137\n\n\n  LIST OF ILLUSTRATIONS\n\n  _IN COLOUR_\n\n\n  "How now?" said Scrooge, caustic\n    and cold as ever. "What do you\n    want with me?"                                           _Frontispiece_\n\n  Bob Cratchit went down a slide on\n    Cornhill, at the end of a lane of\n    boys, twenty times, in honour of\n    its being Christmas Eve                                           16\n\n  Nobody under the bed; nobody in\n    the clo ...
#  '\ufeffThe Project Gutenberg eBook of Romeo and Juliet\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: Romeo and Juliet\n\nAuthor: William Shakespeare\n\nRelease date: November 1, 1998 [eBook #1513]\n                Most recently updated: June 19, 2024\n\nLanguage: English\n\nCredits: the PG Shakespeare Team, a team of about twenty Project Gutenberg volunteers\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK ROMEO AND JULIET ***\n\n\n\n\nTHE TRAGEDY OF ROMEO AND JULIET\n\nby William Shakespeare\n\n\n\n\nContents\n\nTHE PROLOGUE.\n\nACT I\nScene I. A public place.\nScene II. A Street.\nScene III. Room in Capulet’s House.\nScene IV. A Street.\nScene V. A Hall in Capulet’s House.\n\nACT II\nCHORUS.\nScene I. An open place adjoining Capulet’s Garden.\nScene II. Capulet’s Garden.\nScene III. Friar Lawrence’s Cell.\nScene IV. A Street.\nScene V. Capulet’s Garden.\nScene VI. Friar Lawrence’s Cell.\n\nACT III\nScene I. A public Place.\nScene II. A Room in Capulet’s House.\nScene III. Friar Lawrence’s cell.\nScene IV. A Room in Capulet’s House.\nScene V. An open Gallery to Juliet’s Chamber, overlooking the Garden.\n\nACT IV\nScene I. Friar Lawrence’s Cell.\nScene II. Hall in Capulet’s House.\nScene III. Juliet’s Chamber.\nScene IV. Hall in Capulet’s House.\nScene V. Juliet’s Chamber; Juliet on the bed.\n\nACT V\nScene I. Mantua. A Street.\nScene II. Friar Lawrence’s Cell.\nScene III. A churchyard; in it a Monument belonging to the Capulets.\n\n\n\n\n Dramatis Personæ\n\nESCALUS, Prince of Verona.\nMERCUTIO, kinsman to the Prince, and friend to Romeo.\nPARIS, a young Nobleman, kinsman to the Prince.\nPage to Paris.\n\nMONTAGUE, head of a Veronese family at feud with the Capulets.\nLADY MONTAGUE, wife to Montague.\nROMEO, son to Montague.\nBENVOLIO, nephew to Montague, and friend to Romeo.\nABRAM, servant to Montague.\nBALTHASAR, servant to Romeo.\n\nCAPULET, head of a Veronese family at feud with the Montagues.\nLADY CAPULET, wife to Capulet.\nJULIET, daughter to Capulet.\nTYBALT, nephew to Lady Capulet.\nCAPULET’S COUSIN, an old man.\nNURSE to Juliet.\nPETER, servant to Juliet’s Nurse.\nSAMPSON, servant to Capulet.\nGREGORY, servant to Capulet.\nServants.\n\nFRIAR LAWRENCE, a Franciscan.\nFRIAR JOHN, of the same Order.\nAn Apothecary.\nCHORUS.\nThree Musicians.\nAn Officer.\nCitizens of Verona; several Men and Women, relations to both houses;\nMaskers, Guards, Watchmen and Attendants.\n\nSCENE. During the greater part of the Play in Verona; once, in the\nFifth Act, at Mantua.\n\n\n\n\nTHE PROLOGUE\n\n\n Enter Chorus.\n\nCHORUS.\nTwo households, both alike in dignity,\nIn fair Verona, where we lay our scene,\nFrom ancient grudge break to new mutiny,\nWhere civil blood makes civil hands unclean.\nFrom forth the fatal loins of these two foes\nA pair of star-cross’d lovers take their life;\nWhose misadventur’d piteous overthrows\nDoth with their death bury their parents’ strife.\nThe fearful passage of their death-mark’d love,\nAnd the continuance of their parents’ rage,\nWhich, but their children’s end, nought could remove,\nIs now the two hours’ traffic of our stage;\nThe which, if you with patient ears attend,\nWhat here shall miss, our toil shall strive to mend.\n\n [_Exit._]\n\n\n\n\nACT I\n\nSCENE I. A public place.\n\n\n Enter Sampson and Gregory armed with swords and bucklers.\n\nSAMPSON.\nGregory, on my word, we’ll not carry coals.\n\nGREGORY.\nNo, for then we should be colliers.\n\nSAMPSON.\nI mean, if we be in choler, we’ll draw.\n\nGREGORY.\nAy, while you live, draw your neck out o’ the collar.\n\nSAMPSON.\nI strike qui ...
#  '\ufeffThe Project Gutenberg eBook of Winnie-the-Pooh\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: Winnie-the-Pooh\n\nAuthor: A. A. Milne\n\nIllustrator: Ernest H. Shepard\n\nRelease date: January 3, 2022 [eBook #67098]\n                Most recently updated: December 28, 2022\n\nLanguage: English\n\nOriginal publication: Canada: McClelland & Stewart, Ltd, 1926\n\nCredits: Greg Weeks, Mary Meehan, Iona Vaughan, David T. Jones and the online Distributed Proofreaders Canada team at http://www.pgdpcanada.net\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK WINNIE-THE-POOH ***\n\n\n\n\n\n                            WINNIE-THE-POOH\n\n                            _BY A. A. MILNE_\n\n\n\n\n                              _JUVENILES_\n\n                        When We Were Very Young\n\n    "_The best book of verses for children_ _ever written._"--A. EDWARD\n    NEWTON in _The Atlantic Monthly_.\n\n              Fourteen Songs from When We Were Very Young\n\n    Words by A. A. Milne. Music by H. Fraser-Simson. Decorations by\n    E. H. Shepard.\n\n                         The King\'s Breakfast\n\n    Words by A. A. Milne. Music by H. Fraser-Simson. Decorations by\n    E. H. Shepard\n\n\n                               _ESSAYS_\n\n                          Not That It Matters\n                          The Sunny Side\n                          If I May\n\n\n                            _MYSTERY STORY_\n\n                         The Red House Mystery\n\n\n\n\n                            WINNIE-THE-POOH\n                            BY A. A. MILNE\n\n                      McCLELLAND & STEWART, LTD.\n\n                      PUBLISHERS  -  -   TORONTO\n\n\n\n\n                        Copyright, Canada, 1926\n                    By McClelland & Stewart, Limited\n                          Publishers, Toronto\n\n                    First  Printing, October, 1926\n                    Second   "       July, 1927\n                     Third   "       December, 1928\n                    Fourth   "       December, 1929\n                     Fifth   "       March, 1931\n\n                           Printed in Canada\n\n\n\n\n                                 TO HER\n\n    HAND IN HAND WE COME\n      CHRISTOPHER ROBIN AND I\n    TO LAY THIS BOOK IN YOUR LAP.\n        SAY YOU\'RE SURPRISED?\n        SAY YOU LIKE IT?\n        SAY IT\'S JUST WHAT YOU WANTED?\n          BECAUSE IT\'S YOURS----\n          BECAUSE WE LOVE YOU.\n\n\n\n\n                              INTRODUCTION\n\nIf you happen to have read another book about Christopher Robin, you may\nremember that he once had a swan (or the swan had Christopher Robin, I\ndon\'t know which) and that he used to call this swan Pooh. That was a\nlong time ago, and when we said good-bye, we took the name with us, as\nwe didn\'t think the swan would want it any more. Well, when Edward Bear\nsaid that he would like an exciting name all to himself, Christopher\nRobin said at once, without stopping to think, that he was\nWinnie-the-Pooh. And he was. So, as I have explained the Pooh part, I\nwill now explain the rest of it.\n\nYou can\'t be in London for long without going to the Zoo. There are some\npeople who begin the Zoo at the beginning, called WAYIN, and walk as\nquickly as they can past every cage until they get to the one called\nWAYOUT, but the nicest people go straight to the animal they love the\nmost, and stay there. So when Christopher Robin goes to the Zoo, he goes\nto where the Polar Bears are, and he whispers something to the third\nkeeper from the left, and doors are unlocked, and we wande ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    tokens = nltk.word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return tokens

# %%
preprocessed_docs = [preprocess(doc) for doc in doc_files]

# %%
[preprocessed_docs[0]]
# Out:
# [['project',
#   'gutenberg',
#   'ebook',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'author',
#   'mark',
#   'twain',
#   'release',
#   'date',
#   'july',
#   'ebook',
#   'recently',
#   'updated',
#   'august',
#   'language',
#   'english',
#   'credit',
#   'david',
#   'widger',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'adventure',
#   'tom',
#   'sawyer',
#   'mark',
#   'twain',
#   'samuel',
#   'langhorne',
#   'clemens',
#   'content',
#   'chapter',
#   'youu',
#   'tomaunt',
#   'polly',
#   'decides',
#   'upon',
#   'dutytom',
#   'practice',
#   'musicthe',
#   'challengea',
#   'private',
#   'entrance',
#   'chapter',
#   'ii',
#   'strong',
#   'temptationsstrategic',
#   'movementsthe',
#   'innocent',
#   'beguiled',
#   'chapter',
#   'iii',
#   'tom',
#   'generaltriumph',
#   'rewarddismal',
#   'felicitycommission',
#   'omission',
#   'chapter',
#   'iv',
#   'mental',
#   'acrobaticsattending',
#   'sundayschoolthe',
#   'superintendentshowing',
#   'offtom',
#   'lionized',
#   'chapter',
#   'v',
#   'useful',
#   'ministerin',
#   'churchthe',
#   'climax',
#   'chapter',
#   'vi',
#   'selfexaminationdentistrythe',
#   'midnight',
#   'charmwitches',
#   'devilscautious',
#   'approacheshappy',
#   'hour',
#   'chapter',
#   'vii',
#   'treaty',
#   'entered',
#   'intoearly',
#   'lessonsa',
#   'mistake',
#   'made',
#   'chapter',
#   'viii',
#   'tom',
#   'decides',
#   'courseold',
#   'scene',
#   'reenacted',
#   'chapter',
#   'ix',
#   'solemn',
#   'situationgrave',
#   'subject',
#   'introducedinjun',
#   'joe',
#   'explains',
#   'chapter',
#   'x',
#   'solemn',
#   'oathterror',
#   'brings',
#   'repentancemental',
#   'punishment',
#   'chapter',
#   'xi',
#   'muff',
#   'potter',
#   'come',
#   'himselftoms',
#   'conscience',
#   'work',
#   'chapter',
#   'xii',
#   'tom',
#   'show',
#   'generosityaunt',
#   'polly',
#   'weakens',
#   'chapter',
#   'xiii',
#   'young',
#   'piratesgoing',
#   'rendezvousthe',
#   'campfire',
#   'talk',
#   'chapter',
#   'xiv',
#   'camplifea',
#   'sensationtom',
#   'steal',
#   'away',
#   'camp',
#   'chapter',
#   'xv',
#   'tom',
#   'reconnoiterslearns',
#   'situationreports',
#   'camp',
#   'chapter',
#   'xvi',
#   'day',
#   'amusementstom',
#   'reveals',
#   'secretthe',
#   'pirate',
#   'take',
#   'lessona',
#   'night',
#   'surprisean',
#   'indian',
#   'war',
#   'chapter',
#   'xvii',
#   'memory',
#   'lost',
#   'heroesthe',
#   'point',
#   'tom',
#   'secret',
#   'chapter',
#   'xviii',
#   'tom',
#   'feeling',
#   'investigatedwonderful',
#   'dreambecky',
#   'thatcher',
#   'overshadowedtom',
#   'becomes',
#   'jealousblack',
#   'revenge',
#   'chapter',
#   'xix',
#   'tom',
#   'tell',
#   'truth',
#   'chapter',
#   'xx',
#   'becky',
#   'dilemmatoms',
#   'nobility',
#   'asserts',
#   'chapter',
#   'xxi',
#   'youthful',
#   'eloquencecompositions',
#   'young',
#   'ladiesa',
#   'lengthy',
#   'visionthe',
#   'boy',
#   'vengeance',
#   'satisfied',
#   'chapter',
#   'xxii',
#   'tom',
#   'confidence',
#   'betrayedexpects',
#   'signal',
#   'punishment',
#   'chapter',
#   'xxiii',
#   'old',
#   'muff',
#   'friendsmuff',
#   'potter',
#   'courtmuff',
#   'potter',
#   'saved',
#   'chapter',
#   'xxiv',
#   'tom',
#   'village',
#   'herodays',
#   'splendor',
#   'night',
#   'horrorpursuit',
#   'injun',
#   'joe',
#   'chapter',
#   'xxv',
#   'king',
#   'diamondssearch',
#   'treasuredead',
#   'people',
#   'ghost',
#   'chapter',
#   'xxvi',
#   'haunted',
#   'housesleepy',
#   'ghostsa',
#   'box',
#   'goldbitter',
#   'luck',
#   'chapter',
#   'xxvii',
#   'doubt',
#   'settledthe',
#   'young',
#   'detective',
#   'chapter',
#   'xxviii',
#   'attempt',
#   'twohuck',
#   'mount',
#   'guard',
#   'chapter',
#   'xxix',
#   'picnichuck',
#   'injun',
#   'joes',
#   'trackthe',
#   'revenge',
#   'jobaid',
#   'widow',
#   'chapter',
#   'xxx',
#   'welshman',
#   'reportshuck',
#   'firethe',
#   'story',
#   'circulated',
#   'new',
#   'sensationhope',
#   'giving',
#   'way',
#   'despair',
#   'chapter',
#   'xxxi',
#   'exploring',
#   'expeditiontrouble',
#   'commenceslost',
#   'cavetotal',
#   'darknessfound',
#   'saved',
#   'chapter',
#   'xxxii',
#   'tom',
#   'tell',
#   'story',
#   'escapetoms',
#   'enemy',
#   'safe',
#   'quarter',
#   'chapter',
#   'xxxiii',
#   'fate',
#   'injun',
#   'joehuck',
#   'tom',
#   'compare',
#   'note',
#   'expedition',
#   'caveprotection',
#   'ghostsan',
#   'awful',
#   'snug',
#   'placea',
#   'reception',
#   'widow',
#   'douglas',
#   'chapter',
#   'xxxiv',
#   'springing',
#   'secretmr',
#   'jones',
#   'surprise',
#   'failure',
#   'chapter',
#   'xxxv',
#   'new',
#   'order',
#   'thingspoor',
#   'hucknew',
#   'adventure',
#   'planned',
#   'illustration',
#   'tom',
#   'sawyer',
#   'tom',
#   'home',
#   'aunt',
#   'polly',
#   'beguiled',
#   'good',
#   'opportunity',
#   'who',
#   'afraid',
#   'late',
#   'home',
#   'jim',
#   'tendin',
#   'business',
#   'aint',
#   'work',
#   'cat',
#   'toy',
#   'amusement',
#   'becky',
#   'thatcher',
#   'paying',
#   'battle',
#   'showing',
#   'amiss',
#   'mary',
#   'tom',
#   'contemplating',
#   'dampened',
#   'ardor',
#   'youth',
#   'boyhood',
#   'using',
#   'barlow',
#   'church',
#   'necessity',
#   'tom',
#   'sundayschool',
#   'hero',
#   'prize',
#   'church',
#   'model',
#   'boy',
#   'church',
#   'choir',
#   'side',
#   'show',
#   'result',
#   'playing',
#   'church',
#   'pinchbug',
#   'sid',
#   'dentistry',
#   'huckleberry',
#   'finn',
#   'mother',
#   'hopkins',
#   'result',
#   'tom',
#   'truthfulness',
#   'tom',
#   'artist',
#   'interrupted',
#   'courtship',
#   'master',
#   'vain',
#   'pleading',
#   'tail',
#   'piece',
#   'grave',
#   'wood',
#   'tom',
#   'meditates',
#   'robin',
#   'hood',
#   'foe',
#   'death',
#   'robin',
#   'hood',
#   'midnight',
#   'tom',
#   'mode',
#   'egress',
#   'tom',
#   'effort',
#   'prayer',
#   'muff',
#   'potter',
#   'outwitted',
#   'graveyard',
#   'forewarning',
#   'disturbing',
#   'muff',
#   'sleep',
#   'tom',
#   'talk',
#   'aunt',
#   'muff',
#   'potter',
#   'suspicious',
#   'incident',
#   'injun',
#   'joes',
#   'two',
#   'victim',
#   'coil',
#   'peter',
#   'aunt',
#   'polly',
#   'seek',
#   'information',
#   'general',
#   'good',
#   'time',
#   'demoralized',
#   'joe',
#   'harper',
#   'board',
#   'first',
#   'prize',
#   'pirate',
#   'ashore',
#   'wild',
#   'life',
#   'pirate',
#   'bath',
#   'pleasant',
#   'stroll',
#   'search',
#   'drowned',
#   'mysterious',
#   'writing',
#   'river',
#   'view',
#   'tom',
#   'saw',
#   'tom',
#   'swim',
#   'river',
#   'taking',
#   'lesson',
#   'pirate',
#   'egg',
#   'market',
#   'tom',
#   'looking',
#   'joes',
#   'knife',
#   'thunder',
#   'storm',
#   'terrible',
#   'slaughter',
#   'mourner',
#   'tom',
#   'proudest',
#   'moment',
#   'amy',
#   'lawrence',
#   'tom',
#   'try',
#   'remember',
#   'hero',
#   'flirtation',
#   'becky',
#   'retaliates',
#   'sudden',
#   'frost',
#   'counterirritation',
#   'aunt',
#   'polly',
#   'tom',
#   'justified',
#   'discovery',
#   'caught',
#   'act',
#   'tom',
#   'astonishes',
#   'school',
#   'literature',
#   'tom',
#   'declaims',
#   'examination',
#   'evening',
#   'exhibition',
#   'prize',
#   'author',
#   'master',
#   'dilemma',
#   'school',
#   'house',
#   'cadet',
#   'happy',
#   'two',
#   'day',
#   'enjoying',
#   'vacation',
#   'stolen',
#   'melon',
#   'judge',
#   'visiting',
#   'prisoner',
#   'tom',
#   'swears',
#   'court',
#   'room',
#   'detective',
#   'tom',
#   'dream',
#   'treasure',
#   'private',
#   'conference',
#   'king',
#   'poor',
#   'fellow',
#   'business',
#   'hanted',
#   'house',
#   'injun',
#   'joe',
#   'greatest',
#   'best',
#   'hidden',
#   'treasure',
#   'unearthed',
#   'boy',
#   'salvation',
#   'room',
#   'next',
#   'day',
#   'conference',
#   'treasure',
#   'uncle',
#   'jake',
#   'buck',
#   'home',
#   'haunted',
#   'room',
#   'run',
#   'life',
#   'mcdougals',
#   'cave',
#   'inside',
#   'cave',
#   'huck',
#   'duty',
#   'rousing',
#   'act',
#   'tail',
#   'piece',
#   'welshman',
#   'result',
#   'sneeze',
#   'cornered',
#   'alarming',
#   'discovery',
#   'tom',
#   'becky',
#   'stir',
#   'town',
#   'tom',
#   'mark',
#   'huck',
#   'question',
#   'widow',
#   'vampire',
#   'wonder',
#   'cave',
#   'attacked',
#   'native',
#   'despair',
#   'wedding',
#   'cake',
#   'new',
#   'terror',
#   'daylight',
#   'turn',
#   'receive',
#   'tom',
#   'becky',
#   'escape',
#   'cave',
#   'fate',
#   'ragged',
#   'man',
#   'treasure',
#   'found',
#   'caught',
#   'last',
#   'drop',
#   'drop',
#   'good',
#   'time',
#   'business',
#   'trip',
#   'got',
#   'last',
#   'tail',
#   'piece',
#   'widow',
#   'douglas',
#   'tom',
#   'back',
#   'statement',
#   'tail',
#   'piece',
#   'huck',
#   'transformed',
#   'comfortable',
#   'high',
#   'society',
#   'contentment',
#   'preface',
#   'adventure',
#   'recorded',
#   'book',
#   'really',
#   'occurred',
#   'one',
#   'two',
#   'experience',
#   'rest',
#   'boy',
#   'schoolmate',
#   'mine',
#   'huck',
#   'finn',
#   'drawn',
#   'life',
#   'tom',
#   'sawyer',
#   'also',
#   'individualhe',
#   'combination',
#   'characteristic',
#   'three',
#   'boy',
#   'knew',
#   'therefore',
#   'belongs',
#   'composite',
#   'order',
#   'architecture',
#   'odd',
#   'superstition',
#   'touched',
#   'upon',
#   'prevalent',
#   'among',
#   'child',
#   'slave',
#   'west',
#   'period',
#   'storythat',
#   'say',
#   'thirty',
#   'forty',
#   'year',
#   'ago',
#   'although',
#   'book',
#   'intended',
#   'mainly',
#   'entertainment',
#   'boy',
#   'girl',
#   'hope',
#   'shunned',
#   'men',
#   'woman',
#   'account',
#   'part',
#   'plan',
#   'try',
#   'pleasantly',
#   'remind',
#   'adult',
#   'felt',
#   'thought',
#   'talked',
#   'queer',
#   'enterprise',
#   'sometimes',
#   'engaged',
#   'author',
#   'hartford',
#   'chapter',
#   'tom',
#   'answer',
#   'tom',
#   'answer',
#   'whats',
#   'gone',
#   'boy',
#   'wonder',
#   'tom',
#   'answer',
#   'old',
#   'lady',
#   'pulled',
#   'spectacle',
#   'looked',
#   'room',
#   'put',
#   'looked',
#   'seldom',
#   'never',
#   'looked',
#   'small',
#   'thing',
#   'boy',
#   'state',
#   'pair',
#   'pride',
#   'heart',
#   'built',
#   'style',
#   'serviceshe',
#   'could',
#   'seen',
#   'pair',
#   'stovelids',
#   'well',
#   'looked',
#   'perplexed',
#   'moment',
#   'said',
#   'fiercely',
#   'still',
#   'loud',
#   'enough',
#   'furniture',
#   'hear',
#   'well',
#   'lay',
#   'get',
#   'hold',
#   'ill',
#   'finish',
#   'time',
#   'bending',
#   'punching',
#   'bed',
#   'broom',
#   'needed',
#   'breath',
#   'punctuate',
#   'punch',
#   'resurrected',
#   'nothing',
#   'cat',
#   'never',
#   'see',
#   'beat',
#   'boy',
#   'went',
#   'open',
#   'door',
#   'stood',
#   'looked',
#   'among',
#   'tomato',
#   'vine',
#   'jimpson',
#   'weed',
#   'constituted',
#   'garden',
#   'tom',
#   'lifted',
#   'voice',
#   'angle',
#   'calculated',
#   'distance',
#   'shouted',
#   'youu',
#   'tom',
#   'slight',
#   'noise',
#   'behind',
#   'turned',
#   'time',
#   'seize',
#   'small',
#   'boy',
#   'slack',
#   'roundabout',
#   'arrest',
#   'flight',
#   'might',
#   'thought',
#   'closet',
#   'nothing',
#   'nothing',
#   'look',
#   'hand',
#   'look',
#   'mouth',
#   'truck',
#   'dont',
#   'know',
#   'aunt',
#   'well',
#   'know',
#   'jamthats',
#   'forty',
#   'time',
#   'ive',
#   'said',
#   'didnt',
#   'let',
#   'jam',
#   'alone',
#   'id',
#   'skin',
#   'hand',
#   'switch',
#   'switch',
#   'hovered',
#   'airthe',
#   'peril',
#   'desperate',
#   'look',
#   'behind',
#   'aunt',
#   'old',
#   'lady',
#   'whirled',
#   'round',
#   'snatched',
#   'skirt',
#   'danger',
#   'lad',
#   'fled',
#   'instant',
#   'scrambled',
#   'high',
#   'boardfence',
#   'disappeared',
#   'aunt',
#   'polly',
#   'stood',
#   'surprised',
#   'moment',
#   'broke',
#   'gentle',
#   'laugh',
#   'hang',
#   'boy',
#   'cant',
#   'never',
#   'learn',
#   'anything',
#   'aint',
#   'played',
#   'trick',
#   'enough',
#   'like',
#   'looking',
#   'time',
#   'old',
#   'fool',
#   'biggest',
#   'fool',
#   'cant',
#   'learn',
#   'old',
#   'dog',
#   'new',
#   'trick',
#   'saying',
#   'goodness',
#   'never',
#   'play',
#   'alike',
#   'two',
#   'day',
#   'body',
#   'know',
#   'whats',
#   'coming',
#   'pear',
#   'know',
#   'long',
#   'torment',
#   'get',
#   'dander',
#   'know',
#   'make',
#   'put',
#   'minute',
#   'make',
#   'laugh',
#   'cant',
#   'hit',
#   'lick',
#   'aint',
#   'duty',
#   'boy',
#   'thats',
#   'lord',
#   'truth',
#   'goodness',
#   'know',
#   'spare',
#   'rod',
#   'spile',
#   'child',
#   'good',
#   'book',
#   'say',
#   'im',
#   'laying',
#   'sin',
#   'suffering',
#   'u',
#   'know',
#   'he',
#   'full',
#   'old',
#   'scratch',
#   'lawsame',
#   'he',
#   'dead',
#   'sister',
#   'boy',
#   'poor',
#   'thing',
#   'aint',
#   'got',
#   'heart',
#   ...]]

# %%
for i, tokens in enumerate(preprocessed_docs):
    print(f"Tokenized Document {i + 1}: {tokens}")
# Out:
# Tokenized Document 1: ['project', 'gutenberg', 'ebook', 'adventure', 'tom', 'sawyer', 'complete', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'adventure', 'tom', 'sawyer', 'complete', 'author', 'mark', 'twain', 'release', 'date', 'july', 'ebook', 'recently', 'updated', 'august', 'language', 'english', 'credit', 'david', 'widger', 'start', 'project', 'gutenberg', 'ebook', 'adventure', 'tom', 'sawyer', 'complete', 'adventure', 'tom', 'sawyer', 'mark', 'twain', 'samuel', 'langhorne', 'clemens', 'content', 'chapter', 'youu', 'tomaunt', 'polly', 'decides', 'upon', 'dutytom', 'practice', 'musicthe', 'challengea', 'private', 'entrance', 'chapter', 'ii', 'strong', 'temptationsstrategic', 'movementsthe', 'innocent', 'beguiled', 'chapter', 'iii', 'tom', 'generaltriumph', 'rewarddismal', 'felicitycommission', 'omission', 'chapter', 'iv', 'mental', 'acrobaticsattending', 'sundayschoolthe', 'superintendentshowing', 'offtom', 'lionized', 'chapter', 'v', 'useful', 'ministerin', 'churchthe', 'climax', 'chapter', 'vi', 'selfexaminationdentistrythe', 'midnight', 'charmwitches', 'devilscautious', 'approacheshappy', 'hour', 'chapter', 'vii', 'treaty', 'entered', 'intoearly', 'lessonsa', 'mistake', 'made', 'chapter', 'viii', 'tom', 'decides', 'courseold', 'scene', 'reenacted', 'chapter', 'ix', 'solemn', 'situationgrave', 'subject', 'introducedinjun', 'joe', 'explains', 'chapter', 'x', 'solemn', 'oathterror', 'brings', 'repentancemental', 'punishment', 'chapter', 'xi', 'muff', 'potter', 'come', 'himselftoms', 'conscience', 'work', 'chapter', 'xii', 'tom', 'show', 'generosityaunt', 'polly', 'weakens', 'chapter', 'xiii', 'young', 'piratesgoing', 'rendezvousthe', 'campfire', 'talk', 'chapter', 'xiv', 'camplifea', 'sensationtom', 'steal', 'away', 'camp', 'chapter', 'xv', 'tom', 'reconnoiterslearns', 'situationreports', 'camp', 'chapter', 'xvi', 'day', 'amusementstom', 'reveals', 'secretthe', 'pirate', 'take', 'lessona', 'night', 'surprisean', 'indian', 'war', 'chapter', 'xvii', 'memory', 'lost', 'heroesthe', 'point', 'tom', 'secret', 'chapter', 'xviii', 'tom', 'feeling', 'investigatedwonderful', 'dreambecky', 'thatcher', 'overshadowedtom', 'becomes', 'jealousblack', 'revenge', 'chapter', 'xix', 'tom', 'tell', 'truth', 'chapter', 'xx', 'becky', 'dilemmatoms', 'nobility', 'asserts', 'chapter', 'xxi', 'youthful', 'eloquencecompositions', 'young', 'ladiesa', 'lengthy', 'visionthe', 'boy', 'vengeance', 'satisfied', 'chapter', 'xxii', 'tom', 'confidence', 'betrayedexpects', 'signal', 'punishment', 'chapter', 'xxiii', 'old', 'muff', 'friendsmuff', 'potter', 'courtmuff', 'potter', 'saved', 'chapter', 'xxiv', 'tom', 'village', 'herodays', 'splendor', 'night', 'horrorpursuit', 'injun', 'joe', 'chapter', 'xxv', 'king', 'diamondssearch', 'treasuredead', 'people', 'ghost', 'chapter', 'xxvi', 'haunted', 'housesleepy', 'ghostsa', 'box', 'goldbitter', 'luck', 'chapter', 'xxvii', 'doubt', 'settledthe', 'young', 'detective', 'chapter', 'xxviii', 'attempt', 'twohuck', 'mount', 'guard', 'chapter', 'xxix', 'picnichuck', 'injun', 'joes', 'trackthe', 'revenge', 'jobaid', 'widow', 'chapter', 'xxx', 'welshman', 'reportshuck', 'firethe', 'story', 'circulated', 'new', 'sensationhope', 'giving', 'way', 'despair', 'chapter', 'xxxi', 'exploring', 'expeditiontrouble', 'commenceslost', 'cavetotal', 'darknessfound', 'saved', 'chapter', 'xxxii', 'tom', 'tell', 'story', 'escapetoms', 'enemy', 'safe', 'quarter', 'chapter', 'xxxiii', 'fate', 'injun', 'joehuck', 'tom', 'compare', 'note', 'expedition', 'caveprotection', 'ghostsan', 'awful', 'snug', 'placea', 'reception', 'widow', 'douglas', 'chapter', 'xxxiv', 'springing', 'secretmr', 'jones', 'surprise', 'failure', 'chapter', 'xxxv', 'new', ...
# Tokenized Document 2: ['project', 'gutenberg', 'ebook', 'yellow', 'wallpaper', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'yellow', 'wallpaper', 'author', 'charlotte', 'perkins', 'gilman', 'release', 'date', 'november', 'ebook', 'recently', 'updated', 'august', 'language', 'english', 'credit', 'anonymous', 'volunteer', 'david', 'widger', 'start', 'project', 'gutenberg', 'ebook', 'yellow', 'wallpaper', 'yellow', 'wallpaper', 'charlotte', 'perkins', 'gilman', 'seldom', 'mere', 'ordinary', 'people', 'like', 'john', 'secure', 'ancestral', 'hall', 'summer', 'colonial', 'mansion', 'hereditary', 'estate', 'would', 'say', 'haunted', 'house', 'reach', 'height', 'romantic', 'felicitybut', 'would', 'asking', 'much', 'fate', 'still', 'proudly', 'declare', 'something', 'queer', 'else', 'let', 'cheaply', 'stood', 'long', 'untenanted', 'john', 'laugh', 'course', 'one', 'expects', 'marriage', 'john', 'practical', 'extreme', 'patience', 'faith', 'intense', 'horror', 'superstition', 'scoff', 'openly', 'talk', 'thing', 'felt', 'seen', 'put', 'figure', 'john', 'physician', 'perhapsi', 'would', 'say', 'living', 'soul', 'course', 'dead', 'paper', 'great', 'relief', 'mindperhaps', 'one', 'reason', 'get', 'well', 'faster', 'see', 'believe', 'sick', 'one', 'physician', 'high', 'standing', 'one', 'husband', 'assures', 'friend', 'relative', 'really', 'nothing', 'matter', 'one', 'temporary', 'nervous', 'depressiona', 'slight', 'hysterical', 'tendencywhat', 'one', 'brother', 'also', 'physician', 'also', 'high', 'standing', 'say', 'thing', 'take', 'phosphate', 'phosphiteswhichever', 'tonic', 'journey', 'air', 'exercise', 'absolutely', 'forbidden', 'work', 'well', 'personally', 'disagree', 'idea', 'personally', 'believe', 'congenial', 'work', 'excitement', 'change', 'would', 'good', 'one', 'write', 'spite', 'exhaust', 'good', 'dealhaving', 'sly', 'else', 'meet', 'heavy', 'opposition', 'sometimes', 'fancy', 'condition', 'le', 'opposition', 'society', 'stimulusbut', 'john', 'say', 'worst', 'thing', 'think', 'condition', 'confess', 'always', 'make', 'feel', 'bad', 'let', 'alone', 'talk', 'house', 'beautiful', 'place', 'quite', 'alone', 'standing', 'well', 'back', 'road', 'quite', 'three', 'mile', 'village', 'make', 'think', 'english', 'place', 'read', 'hedge', 'wall', 'gate', 'lock', 'lot', 'separate', 'little', 'house', 'gardener', 'people', 'delicious', 'garden', 'never', 'saw', 'gardenlarge', 'shady', 'full', 'boxbordered', 'path', 'lined', 'long', 'grapecovered', 'arbor', 'seat', 'greenhouse', 'broken', 'legal', 'trouble', 'believe', 'something', 'heir', 'coheirs', 'anyhow', 'place', 'empty', 'year', 'spoil', 'ghostliness', 'afraid', 'dont', 'carethere', 'something', 'strange', 'housei', 'feel', 'even', 'said', 'john', 'one', 'moonlight', 'evening', 'said', 'felt', 'draught', 'shut', 'window', 'get', 'unreasonably', 'angry', 'john', 'sometimes', 'im', 'sure', 'never', 'used', 'sensitive', 'think', 'due', 'nervous', 'condition', 'john', 'say', 'feel', 'shall', 'neglect', 'proper', 'selfcontrol', 'take', 'pain', 'control', 'myselfbefore', 'leastand', 'make', 'tired', 'dont', 'like', 'room', 'bit', 'wanted', 'one', 'downstairs', 'opened', 'piazza', 'rose', 'window', 'pretty', 'oldfashioned', 'chintz', 'hanging', 'john', 'would', 'hear', 'said', 'one', 'window', 'room', 'two', 'bed', 'near', 'room', 'took', 'another', 'careful', 'loving', 'hardly', 'let', 'stir', 'without', 'special', 'direction', 'schedule', 'prescription', 'hour', 'day', 'take', 'care', 'feel', 'basely', 'ungrateful', 'value', 'said', 'came', 'solely', 'account', 'perfect', 'rest', 'air', 'could', 'get', 'exercise', 'depends', 'strength', 'dear', 'said', 'food', 'somewhat', 'appetite', 'air' ...
# Tokenized Document 3: ['project', 'gutenberg', 'ebook', 'christmas', 'carol', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'christmas', 'carol', 'author', 'charles', 'dickens', 'illustrator', 'arthur', 'rackham', 'release', 'date', 'december', 'ebook', 'language', 'english', 'original', 'publication', 'philadelphia', 'new', 'york', 'j', 'b', 'lippincott', 'company', 'credit', 'produced', 'suzanne', 'shell', 'janet', 'blenkinship', 'online', 'distributed', 'proofreading', 'team', 'httpwwwpgdpnet', 'start', 'project', 'gutenberg', 'ebook', 'christmas', 'carol', 'produced', 'suzanne', 'shell', 'janet', 'blenkinship', 'online', 'distributed', 'proofreading', 'team', 'httpwwwpgdpnet', 'christmas', 'carol', 'illustration', 'said', 'scrooge', 'caustic', 'cold', 'ever', 'want', 'christmas', 'carol', 'illustration', 'charles', 'dickens', 'illustration', 'illustrated', 'arthur', 'rackham', 'illustration', 'j', 'b', 'lippincott', 'company', 'philadelphia', 'new', 'york', 'first', 'published', 'reprinted', 'isbn', 'printed', 'great', 'britain', 'preface', 'endeavoured', 'ghostly', 'little', 'book', 'raise', 'ghost', 'idea', 'shall', 'put', 'reader', 'humour', 'season', 'may', 'haunt', 'house', 'pleasantly', 'one', 'wish', 'lay', 'faithful', 'friend', 'servant', 'c', 'december', 'character', 'bob', 'cratchit', 'clerk', 'ebenezer', 'scrooge', 'peter', 'cratchit', 'son', 'preceding', 'tim', 'cratchit', 'tiny', 'tim', 'cripple', 'youngest', 'son', 'bob', 'cratchit', 'mr', 'fezziwig', 'kindhearted', 'jovial', 'old', 'merchant', 'fred', 'scrooge', 'nephew', 'ghost', 'christmas', 'past', 'phantom', 'showing', 'thing', 'past', 'ghost', 'christmas', 'present', 'spirit', 'kind', 'generous', 'hearty', 'nature', 'ghost', 'christmas', 'yet', 'come', 'apparition', 'showing', 'shadow', 'thing', 'yet', 'may', 'happen', 'ghost', 'jacob', 'marley', 'spectre', 'scrooge', 'former', 'partner', 'business', 'joe', 'marinestore', 'dealer', 'receiver', 'stolen', 'good', 'ebenezer', 'scrooge', 'grasping', 'covetous', 'old', 'man', 'surviving', 'partner', 'firm', 'scrooge', 'marley', 'mr', 'topper', 'bachelor', 'dick', 'wilkins', 'fellow', 'apprentice', 'scrooge', 'belle', 'comely', 'matron', 'old', 'sweetheart', 'scrooge', 'caroline', 'wife', 'one', 'scrooge', 'debtor', 'mr', 'cratchit', 'wife', 'bob', 'cratchit', 'belinda', 'martha', 'cratchit', 'daughter', 'preceding', 'mr', 'dilber', 'laundress', 'fan', 'sister', 'scrooge', 'mr', 'fezziwig', 'worthy', 'partner', 'mr', 'fezziwig', 'content', 'stave', 'onemarleys', 'ghost', 'stave', 'twothe', 'first', 'three', 'spirit', 'stave', 'threethe', 'second', 'three', 'spirit', 'stave', 'fourthe', 'last', 'spirit', 'stave', 'fivethe', 'end', 'list', 'illustration', 'colour', 'said', 'scrooge', 'caustic', 'cold', 'ever', 'want', 'frontispiece', 'bob', 'cratchit', 'went', 'slide', 'cornhill', 'end', 'lane', 'boy', 'twenty', 'time', 'honour', 'christmas', 'eve', 'nobody', 'bed', 'nobody', 'closet', 'nobody', 'dressinggown', 'hanging', 'suspicious', 'attitude', 'wall', 'air', 'filled', 'phantom', 'wandering', 'hither', 'thither', 'restless', 'haste', 'moaning', 'went', 'old', 'fezziwig', 'stood', 'dance', 'mr', 'fezziwig', 'flushed', 'boisterous', 'group', 'laden', 'christmas', 'toy', 'present', 'way', 'went', 'plump', 'sister', 'lace', 'tucker', 'said', 'one', 'returned', 'well', 'said', 'first', 'old', 'scratch', 'got', 'last', 'hey', 'call', 'said', 'joe', 'bedcurtains', 'ah', 'returned', 'woman', 'laughing', 'bedcurtains', 'dont', 'mean', 'say', 'took', 'em', 'ring', 'lying', 'said', 'joe', 'yes', 'replied', 'woman', 'uncle', 'scrooge', 'come', 'dinner', 'let', 'fred', 'ill', 'tell', 'friend', 'said', 'scrooge', 'going', 's ...
# Tokenized Document 4: ['project', 'gutenberg', 'ebook', 'romeo', 'juliet', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'romeo', 'juliet', 'author', 'william', 'shakespeare', 'release', 'date', 'november', 'ebook', 'recently', 'updated', 'june', 'language', 'english', 'credit', 'pg', 'shakespeare', 'team', 'team', 'twenty', 'project', 'gutenberg', 'volunteer', 'start', 'project', 'gutenberg', 'ebook', 'romeo', 'juliet', 'tragedy', 'romeo', 'juliet', 'william', 'shakespeare', 'content', 'prologue', 'act', 'scene', 'public', 'place', 'scene', 'ii', 'street', 'scene', 'iii', 'room', 'capulets', 'house', 'scene', 'iv', 'street', 'scene', 'v', 'hall', 'capulets', 'house', 'act', 'ii', 'chorus', 'scene', 'open', 'place', 'adjoining', 'capulets', 'garden', 'scene', 'ii', 'capulets', 'garden', 'scene', 'iii', 'friar', 'lawrence', 'cell', 'scene', 'iv', 'street', 'scene', 'v', 'capulets', 'garden', 'scene', 'vi', 'friar', 'lawrence', 'cell', 'act', 'iii', 'scene', 'public', 'place', 'scene', 'ii', 'room', 'capulets', 'house', 'scene', 'iii', 'friar', 'lawrence', 'cell', 'scene', 'iv', 'room', 'capulets', 'house', 'scene', 'v', 'open', 'gallery', 'juliets', 'chamber', 'overlooking', 'garden', 'act', 'iv', 'scene', 'friar', 'lawrence', 'cell', 'scene', 'ii', 'hall', 'capulets', 'house', 'scene', 'iii', 'juliets', 'chamber', 'scene', 'iv', 'hall', 'capulets', 'house', 'scene', 'v', 'juliets', 'chamber', 'juliet', 'bed', 'act', 'v', 'scene', 'mantua', 'street', 'scene', 'ii', 'friar', 'lawrence', 'cell', 'scene', 'iii', 'churchyard', 'monument', 'belonging', 'capulets', 'dramatis', 'person', 'escalus', 'prince', 'verona', 'mercutio', 'kinsman', 'prince', 'friend', 'romeo', 'paris', 'young', 'nobleman', 'kinsman', 'prince', 'page', 'paris', 'montague', 'head', 'veronese', 'family', 'feud', 'capulets', 'lady', 'montague', 'wife', 'montague', 'romeo', 'son', 'montague', 'benvolio', 'nephew', 'montague', 'friend', 'romeo', 'abram', 'servant', 'montague', 'balthasar', 'servant', 'romeo', 'capulet', 'head', 'veronese', 'family', 'feud', 'montagues', 'lady', 'capulet', 'wife', 'capulet', 'juliet', 'daughter', 'capulet', 'tybalt', 'nephew', 'lady', 'capulet', 'capulets', 'cousin', 'old', 'man', 'nurse', 'juliet', 'peter', 'servant', 'juliets', 'nurse', 'sampson', 'servant', 'capulet', 'gregory', 'servant', 'capulet', 'servant', 'friar', 'lawrence', 'franciscan', 'friar', 'john', 'order', 'apothecary', 'chorus', 'three', 'musician', 'officer', 'citizen', 'verona', 'several', 'men', 'woman', 'relation', 'house', 'masker', 'guard', 'watchman', 'attendant', 'scene', 'greater', 'part', 'play', 'verona', 'fifth', 'act', 'mantua', 'prologue', 'enter', 'chorus', 'chorus', 'two', 'household', 'alike', 'dignity', 'fair', 'verona', 'lay', 'scene', 'ancient', 'grudge', 'break', 'new', 'mutiny', 'civil', 'blood', 'make', 'civil', 'hand', 'unclean', 'forth', 'fatal', 'loin', 'two', 'foe', 'pair', 'starcrossd', 'lover', 'take', 'life', 'whose', 'misadventurd', 'piteous', 'overthrow', 'doth', 'death', 'bury', 'parent', 'strife', 'fearful', 'passage', 'deathmarkd', 'love', 'continuance', 'parent', 'rage', 'childrens', 'end', 'nought', 'could', 'remove', 'two', 'hour', 'traffic', 'stage', 'patient', 'ear', 'attend', 'shall', 'miss', 'toil', 'shall', 'strive', 'mend', 'exit', 'act', 'scene', 'public', 'place', 'enter', 'sampson', 'gregory', 'armed', 'sword', 'buckler', 'sampson', 'gregory', 'word', 'well', 'carry', 'coal', 'gregory', 'collier', 'sampson', 'mean', 'choler', 'well', 'draw', 'gregory', 'ay', 'live', 'draw', 'neck', 'collar', 'sampson', 'strike', 'quickly', 'moved', 'gregory', 'thou', 'art', 'quickly', 'moved', 'strike', 'sampson', 'dog', 'house', 'montag ...
# Tokenized Document 5: ['project', 'gutenberg', 'ebook', 'winniethepooh', 'ebook', 'use', 'anyone', 'anywhere', 'united', 'state', 'part', 'world', 'cost', 'almost', 'restriction', 'whatsoever', 'may', 'copy', 'give', 'away', 'reuse', 'term', 'project', 'gutenberg', 'license', 'included', 'ebook', 'online', 'wwwgutenbergorg', 'located', 'united', 'state', 'check', 'law', 'country', 'located', 'using', 'ebook', 'title', 'winniethepooh', 'author', 'milne', 'illustrator', 'ernest', 'h', 'shepard', 'release', 'date', 'january', 'ebook', 'recently', 'updated', 'december', 'language', 'english', 'original', 'publication', 'canada', 'mcclelland', 'stewart', 'ltd', 'credit', 'greg', 'week', 'mary', 'meehan', 'iona', 'vaughan', 'david', 'jones', 'online', 'distributed', 'proofreader', 'canada', 'team', 'httpwwwpgdpcanadanet', 'start', 'project', 'gutenberg', 'ebook', 'winniethepooh', 'winniethepooh', 'milne', 'juvenile', 'young', 'best', 'book', 'verse', 'child', 'ever', 'writtena', 'edward', 'newton', 'atlantic', 'monthly', 'fourteen', 'song', 'young', 'word', 'milne', 'music', 'h', 'frasersimson', 'decoration', 'e', 'h', 'shepard', 'king', 'breakfast', 'word', 'milne', 'music', 'h', 'frasersimson', 'decoration', 'e', 'h', 'shepard', 'essay', 'matter', 'sunny', 'side', 'may', 'mystery', 'story', 'red', 'house', 'mystery', 'winniethepooh', 'milne', 'mcclelland', 'stewart', 'ltd', 'publisher', 'toronto', 'copyright', 'canada', 'mcclelland', 'stewart', 'limited', 'publisher', 'toronto', 'first', 'printing', 'october', 'second', 'july', 'third', 'december', 'fourth', 'december', 'fifth', 'march', 'printed', 'canada', 'hand', 'hand', 'come', 'christopher', 'robin', 'lay', 'book', 'lap', 'say', 'youre', 'surprised', 'say', 'like', 'say', 'wanted', 'love', 'introduction', 'happen', 'read', 'another', 'book', 'christopher', 'robin', 'may', 'remember', 'swan', 'swan', 'christopher', 'robin', 'dont', 'know', 'used', 'call', 'swan', 'pooh', 'long', 'time', 'ago', 'said', 'goodbye', 'took', 'name', 'u', 'didnt', 'think', 'swan', 'would', 'want', 'well', 'edward', 'bear', 'said', 'would', 'like', 'exciting', 'name', 'christopher', 'robin', 'said', 'without', 'stopping', 'think', 'winniethepooh', 'explained', 'pooh', 'part', 'explain', 'rest', 'cant', 'london', 'long', 'without', 'going', 'zoo', 'people', 'begin', 'zoo', 'beginning', 'called', 'wayin', 'walk', 'quickly', 'past', 'every', 'cage', 'get', 'one', 'called', 'wayout', 'nicest', 'people', 'go', 'straight', 'animal', 'love', 'stay', 'christopher', 'robin', 'go', 'zoo', 'go', 'polar', 'bear', 'whisper', 'something', 'third', 'keeper', 'left', 'door', 'unlocked', 'wander', 'dark', 'passage', 'steep', 'stair', 'last', 'come', 'special', 'cage', 'cage', 'opened', 'trot', 'something', 'brown', 'furry', 'happy', 'cry', 'oh', 'bear', 'christopher', 'robin', 'rush', 'arm', 'bear', 'name', 'winnie', 'show', 'good', 'name', 'bear', 'funny', 'thing', 'cant', 'remember', 'whether', 'winnie', 'called', 'pooh', 'pooh', 'winnie', 'know', 'forgotten', 'written', 'far', 'piglet', 'looked', 'said', 'squeaky', 'voice', 'dear', 'piglet', 'said', 'whole', 'book', 'pooh', 'squeaked', 'see', 'jealous', 'think', 'pooh', 'grand', 'introduction', 'pooh', 'favourite', 'course', 'there', 'denying', 'piglet', 'come', 'good', 'many', 'thing', 'pooh', 'miss', 'cant', 'take', 'pooh', 'school', 'without', 'everybody', 'knowing', 'piglet', 'small', 'slip', 'pocket', 'comforting', 'feel', 'quite', 'sure', 'whether', 'twice', 'seven', 'twelve', 'twentytwo', 'sometimes', 'slip', 'good', 'look', 'inkpot', 'way', 'got', 'education', 'pooh', 'pooh', 'doesnt', 'mind', 'brain', 'havent', 'say', 'others', 'saying', 'u', 'perhaps', 'best', 'thing', 'stop', 'writing', 'introduction', 'get', 'book', 'content', 'introduced', 'winniethepooh', 'bee', 'story', 'begin', 'ii', 'pooh', 'go', 'visiting', 'get', 'tight', 'place', 'iii', 'pooh', 'piglet', 'go', 'hunting', 'nearly', 'catch', 'woozle', 'iv', 'eeyore', 'loses', 'tail', 'pooh', 'fin ...

# %%
def term_frequency(term, document):
    return document.count(term) / len(document)

# %%
def inverse_document_frequency(term, all_documents):
    num_docs_containing_term = sum(1 for doc in all_documents if term in doc)
    return math.log(len(all_documents) / (1 + num_docs_containing_term))

# %%
def compute_tfidf(document, all_documents, vocab):
    tfidf_vector = []
    for term in vocab:
        tf = term_frequency(term, document)
        idf = inverse_document_frequency(term, all_documents)
        tfidf_vector.append(tf * idf)
    return np.array(tfidf_vector)

# %%
vocab = set([word for doc in preprocessed_docs for word in doc])
vocab = sorted(vocab)

# %%
vocab
# Out:
# ['aaa',
#  'aadead',
#  'abandoned',
#  'abash',
#  'abashed',
#  'abate',
#  'abbey',
#  'abed',
#  'abel',
#  'abhorred',
#  'abhors',
#  'abide',
#  'abject',
#  'ablaze',
#  'able',
#  'ableeding',
#  'ableto',
#  'aboard',
#  'abode',
#  'abounding',
#  'aboundst',
#  'aboutthat',
#  'aboutthen',
#  'abraham',
#  'abram',
#  'abreast',
#  'abroach',
#  'abroad',
#  'absent',
#  'absently',
#  'absentminded',
#  'absentmindedness',
#  'absolutely',
#  'absolvd',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'abstain',
#  'absurd',
#  'absurdthe',
#  'abundance',
#  'abundant',
#  'abusd',
#  'abuse',
#  'abused',
#  'abusing',
#  'abyss',
#  'academy',
#  'accent',
#  'accept',
#  'accepted',
#  'accepting',
#  'access',
#  'accessed',
#  'accessible',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accommodate',
#  'accompanied',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishing',
#  'accord',
#  'accordance',
#  'according',
#  'accosted',
#  'account',
#  'accoutrement',
#  'accuracy',
#  'accursd',
#  'accused',
#  'accusing',
#  'accustomd',
#  'accustomed',
#  'ache',
#  'ached',
#  'achieve',
#  'achieved',
#  'achievement',
#  'aching',
#  'acknowledge',
#  'acorn',
#  'acquaint',
#  'acquaintance',
#  'acquainted',
#  'acquire',
#  'acquired',
#  'acquirement',
#  'acre',
#  'acrobaticsattending',
#  'across',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'active',
#  'activity',
#  'actual',
#  'actually',
#  'adamant',
#  'adamantine',
#  'adapted',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'addle',
#  'address',
#  'addressed',
#  'addressing',
#  'adherent',
#  'adieu',
#  'adjacent',
#  'adjoining',
#  'adjusted',
#  'adjustment',
#  'administered',
#  'administrator',
#  'admirable',
#  'admiration',
#  'admired',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'admit',
#  'admitted',
#  'adoa',
#  'adoing',
#  'adoration',
#  'adored',
#  'adorn',
#  'adorned',
#  'adream',
#  'adult',
#  'advancd',
#  'advance',
#  'advanced',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adventurous',
#  'adversary',
#  'adversity',
#  'advice',
#  'advise',
#  'afeard',
#  'affability',
#  'affair',
#  'affect',
#  'affected',
#  'affecting',
#  'affection',
#  'affectionate',
#  'afflicted',
#  'afflicting',
#  'affliction',
#  'afford',
#  'afforded',
#  'affords',
#  'affray',
#  'affright',
#  'affront',
#  'afire',
#  'afishing',
#  'afloat',
#  'afluttering',
#  'afore',
#  'afraid',
#  'afraidim',
#  'afterhours',
#  'afternoon',
#  'afterward',
#  'afterwards',
#  'afteryears',
#  'againaimlesslysimply',
#  'againand',
#  'againben',
#  'againfor',
#  'againnow',
#  'againthey',
#  'agatestone',
#  'age',
#  'aged',
#  'agelong',
#  'agent',
#  'aggravate',
#  'aggravated',
#  'agile',
#  'agility',
#  'agin',
#  'agitated',
#  'agitation',
#  'ago',
#  'agoing',
#  'agonised',
#  'agony',
#  'agree',
#  'agreeable',
#  'agreed',
#  'agreement',
#  'agrees',
#  'ague',
#  'ah',
#  'aha',
#  'ahead',
#  'aheadill',
#  'ai',
#  'aid',
#  'aidesdecamp',
#  'ail',
#  'ailing',
#  'ailment',
#  'aimd',
#  'aimed',
#  'aint',
#  'air',
#  'airily',
#  'airthe',
#  'airy',
#  'aisle',
#  'aisleand',
#  'ala',
#  'alabama',
#  'alack',
#  'alacrity',
#  'aladdin',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alderman',
#  'ale',
#  'alert',
#  'alexander',
#  'alfred',
#  'ali',
#  'alike',
#  'alive',
#  'alla',
#  'allcheering',
#  'alley',
#  'alliance',
#  'allied',
#  'alligator',
#  'allits',
#  'allofus',
#  'allow',
#  'allowance',
#  'allowed',
#  'allowing',
#  'alloy',
#  'alloythe',
#  'allseeing',
#  'allthe',
#  'allusion',
#  'ally',
#  'almond',
#  'almost',
#  'almshouse',
#  'aloft',
#  'alone',
#  'alonetoo',
#  'along',
#  'alongside',
#  'aloof',
#  'aloud',
#  'alphabet',
#  'already',
#  'alreadyit',
#  'also',
#  'alsobut',
#  'alsothat',
#  'altar',
#  'alteration',
#  'altered',
#  'alternate',
#  'alternation',
#  'although',
#  'altitude',
#  'altogether',
#  'altogetherits',
#  'always',
#  'alwaysits',
#  'alwaysmost',
#  'amans',
#  'amassed',
#  'amazd',
#  'amazed',
#  'amazement',
#  'ambiguity',
#  'ambition',
#  'ambling',
#  'ambuscade',
#  'ambuscados',
#  'ambush',
#  'amen',
#  'amended',
#  'amends',
#  'ameowing',
#  'amerce',
#  'america',
#  'amid',
#  'amidships',
#  'amiss',
#  'ammunition',
#  'among',
#  'amongst',
#  'amorous',
#  'amount',
#  'amounted',
#  'ample',
#  'amuse',
#  'amusement',
#  'amusementstom',
#  'amy',
#  'amys',
#  'analyze',
#  'analyzed',
#  'anatomy',
#  'anatomycarried',
#  'ancestor',
#  'ancestral',
#  'ancient',
#  'anda',
#  'andafterwards',
#  'andand',
#  'andgodden',
#  'andiron',
#  'andironknob',
#  'andwhat',
#  'anecdote',
#  'angel',
#  'angelic',
#  'angelica',
#  'angelical',
#  'anger',
#  'angerd',
#  'angle',
#  'angry',
#  'angryasked',
#  'anguish',
#  'anguished',
#  'animal',
#  'animation',
#  'animosity',
#  'ankle',
#  'announced',
#  'announcement',
#  'annoyance',
#  'anon',
#  'anonymous',
#  'another',
#  'anothers',
#  'anotherthats',
#  'anotherwhateveritisand',
#  'anselmo',
#  'answer',
#  'answered',
#  'answering',
#  'answernothing',
#  'ant',
#  'antelope',
#  'antic',
#  'anticipated',
#  'anticipation',
#  'antique',
#  'antony',
#  'anxiety',
#  'anxious',
#  'anxiously',
#  'anybody',
#  'anybodyseen',
#  'anybodywhacks',
#  'anybodywill',
#  'anyhow',
#  'anyhowit',
#  'anyone',
#  'anything',
#  'anythingcould',
#  'anyway',
#  'anywayand',
#  'anywaybut',
#  'anyways',
#  'anywhere',
#  'anywhers',
#  'apace',
#  'apart',
#  'apartment',
#  'apathy',
#  'ape',
#  'apiece',
#  'apiecethere',
#  'apology',
#  'apoplectic',
#  'apostle',
#  'apothecary',
#  'appalled',
#  'appalling',
#  'apparel',
#  'apparelld',
#  'apparently',
#  'apparition',
#  'appealdid',
#  'appealed',
#  'appealing',
#  'appealingly',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'appeased',
#  'appertaining',
#  'appetite',
#  'applauded',
#  'applause',
#  'applausive',
#  'apple',
#  'applicable',
#  'application',
#  'applied',
#  'apply',
#  'appoint',
#  'appointed',
#  'appointment',
#  'appraised',
#  'appreciated',
#  'apprehend',
#  'apprehension',
#  'apprehensionfor',
#  'apprehensive',
#  'apprehensively',
#  'apprentice',
#  'apprenticed',
#  'approach',
#  'approached',
#  'approacheshappy',
#  'approaching',
#  'appropriate',
#  'approving',
#  'april',
#  'apron',
#  'apt',
#  'aqua',
#  'arabesque',
#  'arbitrating',
#  'arbor',
#  'architecture',
#  'archive',
#  'archway',
#  'ardor',
#  'aready',
#  'aredoing',
#  'argue',
#  'argues',
#  'arguing',
#  'argument',
#  'arise',
#  'aristocracy',
#  'arithmeticwhy',
#  'arm',
#  'armchair',
#  'armd',
#  'armed',
#  'armour',
#  'armslength',
#  'army',
#  'aromatic',
#  'arose',
#  'arosehostile',
#  'around',
#  'aroundsmiled',
#  'aroused',
#  'arranged',
#  'arranging',
#  'array',
#  'arrayed',
#  'arrest',
#  'arrival',
#  'arrived',
#  'arrives',
#  'arriving',
#  'arrow',
#  'art',
#  'artful',
#  'arthur',
#  'artifice',
#  'artificial',
#  'artillery',
#  'artist',
#  'artistic',
#  'artlessly',
#  'arustling',
#  'as',
#  'ascend',
#  'ascent',
#  'ascii',
#  'ash',
#  'ashamd',
#  'ashamed',
#  'ashore',
#  'aside',
#  'asis',
#  'asitting',
#  'asiwassaying',
#  'ask',
#  'askd',
#  'asked',
#  'askeddimly',
#  'asking',
#  'asks',
#  'asleep',
#  'asmoking',
#  'aspect',
#  'aspiration',
#  'aspird',
#  'assailing',
#  'assembled',
#  'assembling',
#  'assembly',
#  'assent',
#  'assented',
#  'assert',
#  'asserts',
#  'assign',
#  'assigned',
#  'assist',
#  'assistance',
#  'assistant',
#  'assisted',
#  'associate',
#  'associated',
#  'assumed',
#  'assure',
#  'assured',
#  'assures',
#  'assyrian',
#  'ast',
#  'astanding',
#  'astonish',
#  'astonished',
#  'astonishes',
#  'astonishment',
#  'astounding',
#  'astride',
#  'astronomer',
#  'asunder',
#  'aswimming',
#  'aswimmingdernd',
#  'ate',
#  'athwart',
#  'atlantic',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atomies',
#  'atrocious',
#  'attach',
#  'attached',
#  'attack',
#  'attacked',
#  'attain',
#  'attempt',
#  'attempted',
#  'attend',
#  'attendant',
#  'attended',
#  'attending',
#  'attends',
#  'attention',
#  'attentive',
#  'attentively',
#  'attested',
#  'attic',
#  'attire',
#  'attired',
#  'attitude',
#  'attorney',
#  'attract',
#  'attracted',
#  'attraction',
#  'attractive',
#  'attrition',
#  'aturning',
#  'audacious',
#  'audible',
#  'audibly',
#  'audience',
#  'auditory',
#  'aught',
#  'augmenting',
#  'august',
#  'aunt',
#  'auntie',
#  'auntiecertain',
#  'auntiei',
#  'aunty',
#  'auntyou',
#  'aurora',
#  'auspicesthere',
#  'auspicious',
#  'austin',
#  'author',
#  'authority',
#  'available',
#  'avarice',
#  'avariciously',
#  'avenged',
#  'avenger',
#  'avenue',
#  'average',
#  'aversion',
#  'avert',
#  'averted',
#  'avocation',
#  'avoid',
#  'avoided',
#  'awaiting',
#  'awake',
#  'awakened',
#  'awakeoh',
#  'awaking',
#  'aware',
#  'away',
#  'awayblessed',
#  'awayever',
#  'awayhe',
#  'awayso',
#  'awaysomewhat',
#  'awayyou',
#  'awe',
#  'aweary',
#  'awed',
#  'aweinspiring',
#  'awful',
#  'awfuland',
#  'awfulest',
#  'awfully',
#  'awhile',
#  'awhilestand',
#  'awishing',
#  'awitching',
#  'awkward',
#  'awkwardly',
#  'awoke',
#  'awtake',
#  'ax',
#  'axe',
#  'ay',
#  'ayeaye',
#  'b',
#  'baba',
#  'babe',
#  'baby',
#  'bachelor',
#  'back',
#  'backards',
#  'backbone',
#  'backed',
#  'backhanded',
#  'backpayments',
#  'backshop',
#  'backward',
#  'backwards',
#  'backyard',
#  'bacon',
#  'bad',
#  'badand',
#  'badat',
#  'bade',
#  'badly',
#  'badst',
#  'badtoo',
#  'baffled',
#  'bag',
#  'baggage',
#  'bagged',
#  'bah',
#  'bail',
#  'bailing',
#  'bait',
#  'bakd',
#  'baker',
#  'bakes',
#  'baking',
#  'balance',
#  'balancing',
#  'bald',
#  'baleful',
#  'balefully',
#  'ball',
#  'ballon',
#  'balloon',
#  'ballroom',
#  'balm',
#  'balmy',
#  'balthasar',
#  'balustrade',
#  'band',
#  'bandage',
#  'bandy',
#  'bandying',
#  'bang',
#  'banged',
#  'banging',
#  'banishd',
#  'banished',
#  'banishedto',
#  'banishment',
#  'banister',
#  'bank',
#  'banker',
#  'banknote',
#  'bankrout',
#  'bankrupted',
#  'banquet',
#  'baptisd',
#  'bar',
#  'bare',
#  'bared',
#  'barefoot',
#  'barelegged',
#  'barely',
#  'bareness',
#  'barer',
#  'bargain',
#  'bark',
#  'barking',
#  'barl',
#  'barleycorn',
#  'barlow',
#  'barred',
#  'barrel',
#  'barren',
#  'barrow',
#  'base',
#  'based',
#  'basely',
#  'basin',
#  'basket',
#  'basking',
#  'bass',
#  'bat',
#  'bated',
#  'bath',
#  'bathing',
#  'bathwater',
#  'bating',
#  'battery',
#  'battle',
#  'battled',
#  'battlement',
#  'bauble',
#  'bawd',
#  'bawdy',
#  'bay',
#  'baying',
#  'bb',
#  'beaded',
#  'beam',
#  'beamed',
#  'beaming',
#  'bean',
#  'beand',
#  'bear',
#  'beard',
#  'bearer',
#  'bearing',
#  'beast',
#  'beat',
#  'beaten',
#  'beating',
#  'beauteous',
#  'beautiful',
#  'beautify',
#  'beauty',
#  'became',
#  'beckoned',
#  'becky',
#  'beckyhe',
#  'beckyill',
#  'beckypleadingly',
#  'beckys',
#  'beckywere',
#  'become',
#  'becomed',
#  'becomes',
#  'becoming',
#  'becuz',
#  'bed',
#  'beda',
#  'bedaubd',
#  'bedchamber',
#  'bedclothes',
#  'bedcurtains',
#  'bedded',
#  'bedeck',
#  'bedight',
#  'bedit',
#  'bedlam',
#  'bedon',
#  'bedpost',
#  'bedridden',
#  'bedroom',
#  'bedside',
#  'bedstead',
#  'bedtime',
#  'bedvalance',
#  'bee',
#  'beech',
#  'beechtree',
#  'beef',
#  'beehive',
#  'beer',
#  'beetle',
#  'beetlebrows',
#  'beetling',
#  'befits',
#  'befitted',
#  'beforehand',
#  'beforeit',
#  'beforethough',
#  'beforewent',
#  'befriend',
#  'befriended',
#  'beg',
#  'began',
#  'beganhesitatingly',
#  'beggar',
#  'beggarly',
#  'beggarmaid',
#  'beggary',
#  'begged',
#  'begging',
#  'begin',
#  'beginner',
#  'beginning',
#  'begone',
#  'begot',
#  'beguild',
#  'beguiled',
#  'begun',
#  'behalf',
#  'behave',
#  'behavior',
#  'behaviour',
#  'beheld',
#  'behest',
#  'behind',
#  'behindhand',
#  'behindthat',
#  'behindtheears',
#  'behold',
#  'beholden',
#  'behoveful',
#  'being',
#  'belated',
#  'belief',
#  'believe',
#  'believeand',
#  'believed',
#  'belinda',
#  'belittled',
#  'bell',
#  'belle',
#  'belleverythings',
#  'bellpull',
#  'bellrope',
#  'belong',
#  'belonged',
#  'belonging',
#  'belongs',
#  'belovd',
#  'beloved',
#  'belshazzar',
#  'belt',
#  'belting',
#  'ben',
#  'bench',
#  'bend',
#  'bending',
#  'beneath',
#  'benedicite',
#  'benediction',
#  'benefice',
#  'benefit',
#  'benevolence',
#  'benjamin',
#  'benny',
#  'bent',
#  'benton',
#  'benvolio',
#  'bepaint',
#  'bereaved',
#  'bereft',
#  'berhyme',
#  'berry',
#  'berth',
#  'bescreend',
#  'beseech',
#  'beseeching',
#  'beseeming',
#  'beshrew',
#  'beside',
#  'besides',
#  'besidesexcuse',
#  'besought',
#  'best',
#  'besthearted',
#  'bestow',
#  'bestowed',
#  'bestride',
#  'bestrides',
#  'bestruck',
#  'bet',
#  'betake',
#  'bethink',
#  'bethought',
#  'betook',
#  'betossed',
#  'betray',
#  'betrayed',
#  'betrayedexpects',
#  'betraying',
#  'betrothd',
#  'better',
#  'betterim',
#  'bettern',
#  'beware',
#  'bewildering',
#  'bewitched',
#  'bewitching',
#  'beyond',
#  'bible',
#  'biblea',
#  'bibleprize',
#  'bibleto',
#  'bid',
#  'bide',
#  'bier',
#  'biffins',
#  'big',
#  'bigger',
#  'biggest',
#  'bight',
#  'bigotry',
#  'bigwell',
#  'bilious',
#  'bill',
#  'billowy',
#  'billy',
#  'binary',
#  'biographical',
#  'bird',
#  'birdlike',
#  'birth',
#  'birthday',
#  'bishop',
#  'bit',
#  'bite',
#  'biting',
#  'bitno',
#  'bitonly',
#  'bitter',
#  'bitterer',
#  'bitterest',
#  'bitterly',
#  'bitterness',
#  'blab',
#  'black',
#  'blackberry',
#  'blackbird',
#  'blackboard',
#  'blackbrowd',
#  'blacker',
#  'blackeyed',
#  'blackhaired',
#  'blackhulled',
#  'blackness',
#  'bladder',
#  'blade',
#  'blame',
#  'blamed',
#  'blaming',
#  'blanc',
#  'blanched',
#  'blanching',
#  'blank',
#  'blanket',
#  'blanketed',
#  'blast',
#  'blasted',
#  'blaze',
#  'blazed',
#  'blazing',
#  'blazon',
#  'bleak',
#  'bled',
#  ...]

# %%
preprocessed_docs
# Out:
# [['project',
#   'gutenberg',
#   'ebook',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'author',
#   'mark',
#   'twain',
#   'release',
#   'date',
#   'july',
#   'ebook',
#   'recently',
#   'updated',
#   'august',
#   'language',
#   'english',
#   'credit',
#   'david',
#   'widger',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'adventure',
#   'tom',
#   'sawyer',
#   'complete',
#   'adventure',
#   'tom',
#   'sawyer',
#   'mark',
#   'twain',
#   'samuel',
#   'langhorne',
#   'clemens',
#   'content',
#   'chapter',
#   'youu',
#   'tomaunt',
#   'polly',
#   'decides',
#   'upon',
#   'dutytom',
#   'practice',
#   'musicthe',
#   'challengea',
#   'private',
#   'entrance',
#   'chapter',
#   'ii',
#   'strong',
#   'temptationsstrategic',
#   'movementsthe',
#   'innocent',
#   'beguiled',
#   'chapter',
#   'iii',
#   'tom',
#   'generaltriumph',
#   'rewarddismal',
#   'felicitycommission',
#   'omission',
#   'chapter',
#   'iv',
#   'mental',
#   'acrobaticsattending',
#   'sundayschoolthe',
#   'superintendentshowing',
#   'offtom',
#   'lionized',
#   'chapter',
#   'v',
#   'useful',
#   'ministerin',
#   'churchthe',
#   'climax',
#   'chapter',
#   'vi',
#   'selfexaminationdentistrythe',
#   'midnight',
#   'charmwitches',
#   'devilscautious',
#   'approacheshappy',
#   'hour',
#   'chapter',
#   'vii',
#   'treaty',
#   'entered',
#   'intoearly',
#   'lessonsa',
#   'mistake',
#   'made',
#   'chapter',
#   'viii',
#   'tom',
#   'decides',
#   'courseold',
#   'scene',
#   'reenacted',
#   'chapter',
#   'ix',
#   'solemn',
#   'situationgrave',
#   'subject',
#   'introducedinjun',
#   'joe',
#   'explains',
#   'chapter',
#   'x',
#   'solemn',
#   'oathterror',
#   'brings',
#   'repentancemental',
#   'punishment',
#   'chapter',
#   'xi',
#   'muff',
#   'potter',
#   'come',
#   'himselftoms',
#   'conscience',
#   'work',
#   'chapter',
#   'xii',
#   'tom',
#   'show',
#   'generosityaunt',
#   'polly',
#   'weakens',
#   'chapter',
#   'xiii',
#   'young',
#   'piratesgoing',
#   'rendezvousthe',
#   'campfire',
#   'talk',
#   'chapter',
#   'xiv',
#   'camplifea',
#   'sensationtom',
#   'steal',
#   'away',
#   'camp',
#   'chapter',
#   'xv',
#   'tom',
#   'reconnoiterslearns',
#   'situationreports',
#   'camp',
#   'chapter',
#   'xvi',
#   'day',
#   'amusementstom',
#   'reveals',
#   'secretthe',
#   'pirate',
#   'take',
#   'lessona',
#   'night',
#   'surprisean',
#   'indian',
#   'war',
#   'chapter',
#   'xvii',
#   'memory',
#   'lost',
#   'heroesthe',
#   'point',
#   'tom',
#   'secret',
#   'chapter',
#   'xviii',
#   'tom',
#   'feeling',
#   'investigatedwonderful',
#   'dreambecky',
#   'thatcher',
#   'overshadowedtom',
#   'becomes',
#   'jealousblack',
#   'revenge',
#   'chapter',
#   'xix',
#   'tom',
#   'tell',
#   'truth',
#   'chapter',
#   'xx',
#   'becky',
#   'dilemmatoms',
#   'nobility',
#   'asserts',
#   'chapter',
#   'xxi',
#   'youthful',
#   'eloquencecompositions',
#   'young',
#   'ladiesa',
#   'lengthy',
#   'visionthe',
#   'boy',
#   'vengeance',
#   'satisfied',
#   'chapter',
#   'xxii',
#   'tom',
#   'confidence',
#   'betrayedexpects',
#   'signal',
#   'punishment',
#   'chapter',
#   'xxiii',
#   'old',
#   'muff',
#   'friendsmuff',
#   'potter',
#   'courtmuff',
#   'potter',
#   'saved',
#   'chapter',
#   'xxiv',
#   'tom',
#   'village',
#   'herodays',
#   'splendor',
#   'night',
#   'horrorpursuit',
#   'injun',
#   'joe',
#   'chapter',
#   'xxv',
#   'king',
#   'diamondssearch',
#   'treasuredead',
#   'people',
#   'ghost',
#   'chapter',
#   'xxvi',
#   'haunted',
#   'housesleepy',
#   'ghostsa',
#   'box',
#   'goldbitter',
#   'luck',
#   'chapter',
#   'xxvii',
#   'doubt',
#   'settledthe',
#   'young',
#   'detective',
#   'chapter',
#   'xxviii',
#   'attempt',
#   'twohuck',
#   'mount',
#   'guard',
#   'chapter',
#   'xxix',
#   'picnichuck',
#   'injun',
#   'joes',
#   'trackthe',
#   'revenge',
#   'jobaid',
#   'widow',
#   'chapter',
#   'xxx',
#   'welshman',
#   'reportshuck',
#   'firethe',
#   'story',
#   'circulated',
#   'new',
#   'sensationhope',
#   'giving',
#   'way',
#   'despair',
#   'chapter',
#   'xxxi',
#   'exploring',
#   'expeditiontrouble',
#   'commenceslost',
#   'cavetotal',
#   'darknessfound',
#   'saved',
#   'chapter',
#   'xxxii',
#   'tom',
#   'tell',
#   'story',
#   'escapetoms',
#   'enemy',
#   'safe',
#   'quarter',
#   'chapter',
#   'xxxiii',
#   'fate',
#   'injun',
#   'joehuck',
#   'tom',
#   'compare',
#   'note',
#   'expedition',
#   'caveprotection',
#   'ghostsan',
#   'awful',
#   'snug',
#   'placea',
#   'reception',
#   'widow',
#   'douglas',
#   'chapter',
#   'xxxiv',
#   'springing',
#   'secretmr',
#   'jones',
#   'surprise',
#   'failure',
#   'chapter',
#   'xxxv',
#   'new',
#   'order',
#   'thingspoor',
#   'hucknew',
#   'adventure',
#   'planned',
#   'illustration',
#   'tom',
#   'sawyer',
#   'tom',
#   'home',
#   'aunt',
#   'polly',
#   'beguiled',
#   'good',
#   'opportunity',
#   'who',
#   'afraid',
#   'late',
#   'home',
#   'jim',
#   'tendin',
#   'business',
#   'aint',
#   'work',
#   'cat',
#   'toy',
#   'amusement',
#   'becky',
#   'thatcher',
#   'paying',
#   'battle',
#   'showing',
#   'amiss',
#   'mary',
#   'tom',
#   'contemplating',
#   'dampened',
#   'ardor',
#   'youth',
#   'boyhood',
#   'using',
#   'barlow',
#   'church',
#   'necessity',
#   'tom',
#   'sundayschool',
#   'hero',
#   'prize',
#   'church',
#   'model',
#   'boy',
#   'church',
#   'choir',
#   'side',
#   'show',
#   'result',
#   'playing',
#   'church',
#   'pinchbug',
#   'sid',
#   'dentistry',
#   'huckleberry',
#   'finn',
#   'mother',
#   'hopkins',
#   'result',
#   'tom',
#   'truthfulness',
#   'tom',
#   'artist',
#   'interrupted',
#   'courtship',
#   'master',
#   'vain',
#   'pleading',
#   'tail',
#   'piece',
#   'grave',
#   'wood',
#   'tom',
#   'meditates',
#   'robin',
#   'hood',
#   'foe',
#   'death',
#   'robin',
#   'hood',
#   'midnight',
#   'tom',
#   'mode',
#   'egress',
#   'tom',
#   'effort',
#   'prayer',
#   'muff',
#   'potter',
#   'outwitted',
#   'graveyard',
#   'forewarning',
#   'disturbing',
#   'muff',
#   'sleep',
#   'tom',
#   'talk',
#   'aunt',
#   'muff',
#   'potter',
#   'suspicious',
#   'incident',
#   'injun',
#   'joes',
#   'two',
#   'victim',
#   'coil',
#   'peter',
#   'aunt',
#   'polly',
#   'seek',
#   'information',
#   'general',
#   'good',
#   'time',
#   'demoralized',
#   'joe',
#   'harper',
#   'board',
#   'first',
#   'prize',
#   'pirate',
#   'ashore',
#   'wild',
#   'life',
#   'pirate',
#   'bath',
#   'pleasant',
#   'stroll',
#   'search',
#   'drowned',
#   'mysterious',
#   'writing',
#   'river',
#   'view',
#   'tom',
#   'saw',
#   'tom',
#   'swim',
#   'river',
#   'taking',
#   'lesson',
#   'pirate',
#   'egg',
#   'market',
#   'tom',
#   'looking',
#   'joes',
#   'knife',
#   'thunder',
#   'storm',
#   'terrible',
#   'slaughter',
#   'mourner',
#   'tom',
#   'proudest',
#   'moment',
#   'amy',
#   'lawrence',
#   'tom',
#   'try',
#   'remember',
#   'hero',
#   'flirtation',
#   'becky',
#   'retaliates',
#   'sudden',
#   'frost',
#   'counterirritation',
#   'aunt',
#   'polly',
#   'tom',
#   'justified',
#   'discovery',
#   'caught',
#   'act',
#   'tom',
#   'astonishes',
#   'school',
#   'literature',
#   'tom',
#   'declaims',
#   'examination',
#   'evening',
#   'exhibition',
#   'prize',
#   'author',
#   'master',
#   'dilemma',
#   'school',
#   'house',
#   'cadet',
#   'happy',
#   'two',
#   'day',
#   'enjoying',
#   'vacation',
#   'stolen',
#   'melon',
#   'judge',
#   'visiting',
#   'prisoner',
#   'tom',
#   'swears',
#   'court',
#   'room',
#   'detective',
#   'tom',
#   'dream',
#   'treasure',
#   'private',
#   'conference',
#   'king',
#   'poor',
#   'fellow',
#   'business',
#   'hanted',
#   'house',
#   'injun',
#   'joe',
#   'greatest',
#   'best',
#   'hidden',
#   'treasure',
#   'unearthed',
#   'boy',
#   'salvation',
#   'room',
#   'next',
#   'day',
#   'conference',
#   'treasure',
#   'uncle',
#   'jake',
#   'buck',
#   'home',
#   'haunted',
#   'room',
#   'run',
#   'life',
#   'mcdougals',
#   'cave',
#   'inside',
#   'cave',
#   'huck',
#   'duty',
#   'rousing',
#   'act',
#   'tail',
#   'piece',
#   'welshman',
#   'result',
#   'sneeze',
#   'cornered',
#   'alarming',
#   'discovery',
#   'tom',
#   'becky',
#   'stir',
#   'town',
#   'tom',
#   'mark',
#   'huck',
#   'question',
#   'widow',
#   'vampire',
#   'wonder',
#   'cave',
#   'attacked',
#   'native',
#   'despair',
#   'wedding',
#   'cake',
#   'new',
#   'terror',
#   'daylight',
#   'turn',
#   'receive',
#   'tom',
#   'becky',
#   'escape',
#   'cave',
#   'fate',
#   'ragged',
#   'man',
#   'treasure',
#   'found',
#   'caught',
#   'last',
#   'drop',
#   'drop',
#   'good',
#   'time',
#   'business',
#   'trip',
#   'got',
#   'last',
#   'tail',
#   'piece',
#   'widow',
#   'douglas',
#   'tom',
#   'back',
#   'statement',
#   'tail',
#   'piece',
#   'huck',
#   'transformed',
#   'comfortable',
#   'high',
#   'society',
#   'contentment',
#   'preface',
#   'adventure',
#   'recorded',
#   'book',
#   'really',
#   'occurred',
#   'one',
#   'two',
#   'experience',
#   'rest',
#   'boy',
#   'schoolmate',
#   'mine',
#   'huck',
#   'finn',
#   'drawn',
#   'life',
#   'tom',
#   'sawyer',
#   'also',
#   'individualhe',
#   'combination',
#   'characteristic',
#   'three',
#   'boy',
#   'knew',
#   'therefore',
#   'belongs',
#   'composite',
#   'order',
#   'architecture',
#   'odd',
#   'superstition',
#   'touched',
#   'upon',
#   'prevalent',
#   'among',
#   'child',
#   'slave',
#   'west',
#   'period',
#   'storythat',
#   'say',
#   'thirty',
#   'forty',
#   'year',
#   'ago',
#   'although',
#   'book',
#   'intended',
#   'mainly',
#   'entertainment',
#   'boy',
#   'girl',
#   'hope',
#   'shunned',
#   'men',
#   'woman',
#   'account',
#   'part',
#   'plan',
#   'try',
#   'pleasantly',
#   'remind',
#   'adult',
#   'felt',
#   'thought',
#   'talked',
#   'queer',
#   'enterprise',
#   'sometimes',
#   'engaged',
#   'author',
#   'hartford',
#   'chapter',
#   'tom',
#   'answer',
#   'tom',
#   'answer',
#   'whats',
#   'gone',
#   'boy',
#   'wonder',
#   'tom',
#   'answer',
#   'old',
#   'lady',
#   'pulled',
#   'spectacle',
#   'looked',
#   'room',
#   'put',
#   'looked',
#   'seldom',
#   'never',
#   'looked',
#   'small',
#   'thing',
#   'boy',
#   'state',
#   'pair',
#   'pride',
#   'heart',
#   'built',
#   'style',
#   'serviceshe',
#   'could',
#   'seen',
#   'pair',
#   'stovelids',
#   'well',
#   'looked',
#   'perplexed',
#   'moment',
#   'said',
#   'fiercely',
#   'still',
#   'loud',
#   'enough',
#   'furniture',
#   'hear',
#   'well',
#   'lay',
#   'get',
#   'hold',
#   'ill',
#   'finish',
#   'time',
#   'bending',
#   'punching',
#   'bed',
#   'broom',
#   'needed',
#   'breath',
#   'punctuate',
#   'punch',
#   'resurrected',
#   'nothing',
#   'cat',
#   'never',
#   'see',
#   'beat',
#   'boy',
#   'went',
#   'open',
#   'door',
#   'stood',
#   'looked',
#   'among',
#   'tomato',
#   'vine',
#   'jimpson',
#   'weed',
#   'constituted',
#   'garden',
#   'tom',
#   'lifted',
#   'voice',
#   'angle',
#   'calculated',
#   'distance',
#   'shouted',
#   'youu',
#   'tom',
#   'slight',
#   'noise',
#   'behind',
#   'turned',
#   'time',
#   'seize',
#   'small',
#   'boy',
#   'slack',
#   'roundabout',
#   'arrest',
#   'flight',
#   'might',
#   'thought',
#   'closet',
#   'nothing',
#   'nothing',
#   'look',
#   'hand',
#   'look',
#   'mouth',
#   'truck',
#   'dont',
#   'know',
#   'aunt',
#   'well',
#   'know',
#   'jamthats',
#   'forty',
#   'time',
#   'ive',
#   'said',
#   'didnt',
#   'let',
#   'jam',
#   'alone',
#   'id',
#   'skin',
#   'hand',
#   'switch',
#   'switch',
#   'hovered',
#   'airthe',
#   'peril',
#   'desperate',
#   'look',
#   'behind',
#   'aunt',
#   'old',
#   'lady',
#   'whirled',
#   'round',
#   'snatched',
#   'skirt',
#   'danger',
#   'lad',
#   'fled',
#   'instant',
#   'scrambled',
#   'high',
#   'boardfence',
#   'disappeared',
#   'aunt',
#   'polly',
#   'stood',
#   'surprised',
#   'moment',
#   'broke',
#   'gentle',
#   'laugh',
#   'hang',
#   'boy',
#   'cant',
#   'never',
#   'learn',
#   'anything',
#   'aint',
#   'played',
#   'trick',
#   'enough',
#   'like',
#   'looking',
#   'time',
#   'old',
#   'fool',
#   'biggest',
#   'fool',
#   'cant',
#   'learn',
#   'old',
#   'dog',
#   'new',
#   'trick',
#   'saying',
#   'goodness',
#   'never',
#   'play',
#   'alike',
#   'two',
#   'day',
#   'body',
#   'know',
#   'whats',
#   'coming',
#   'pear',
#   'know',
#   'long',
#   'torment',
#   'get',
#   'dander',
#   'know',
#   'make',
#   'put',
#   'minute',
#   'make',
#   'laugh',
#   'cant',
#   'hit',
#   'lick',
#   'aint',
#   'duty',
#   'boy',
#   'thats',
#   'lord',
#   'truth',
#   'goodness',
#   'know',
#   'spare',
#   'rod',
#   'spile',
#   'child',
#   'good',
#   'book',
#   'say',
#   'im',
#   'laying',
#   'sin',
#   'suffering',
#   'u',
#   'know',
#   'he',
#   'full',
#   'old',
#   'scratch',
#   'lawsame',
#   'he',
#   'dead',
#   'sister',
#   'boy',
#   'poor',
#   'thing',
#   'aint',
#   'got',
#   'heart',
#   ...],
#  ['project',
#   'gutenberg',
#   'ebook',
#   'yellow',
#   'wallpaper',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'yellow',
#   'wallpaper',
#   'author',
#   'charlotte',
#   'perkins',
#   'gilman',
#   'release',
#   'date',
#   'november',
#   'ebook',
#   'recently',
#   'updated',
#   'august',
#   'language',
#   'english',
#   'credit',
#   'anonymous',
#   'volunteer',
#   'david',
#   'widger',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'yellow',
#   'wallpaper',
#   'yellow',
#   'wallpaper',
#   'charlotte',
#   'perkins',
#   'gilman',
#   'seldom',
#   'mere',
#   'ordinary',
#   'people',
#   'like',
#   'john',
#   'secure',
#   'ancestral',
#   'hall',
#   'summer',
#   'colonial',
#   'mansion',
#   'hereditary',
#   'estate',
#   'would',
#   'say',
#   'haunted',
#   'house',
#   'reach',
#   'height',
#   'romantic',
#   'felicitybut',
#   'would',
#   'asking',
#   'much',
#   'fate',
#   'still',
#   'proudly',
#   'declare',
#   'something',
#   'queer',
#   'else',
#   'let',
#   'cheaply',
#   'stood',
#   'long',
#   'untenanted',
#   'john',
#   'laugh',
#   'course',
#   'one',
#   'expects',
#   'marriage',
#   'john',
#   'practical',
#   'extreme',
#   'patience',
#   'faith',
#   'intense',
#   'horror',
#   'superstition',
#   'scoff',
#   'openly',
#   'talk',
#   'thing',
#   'felt',
#   'seen',
#   'put',
#   'figure',
#   'john',
#   'physician',
#   'perhapsi',
#   'would',
#   'say',
#   'living',
#   'soul',
#   'course',
#   'dead',
#   'paper',
#   'great',
#   'relief',
#   'mindperhaps',
#   'one',
#   'reason',
#   'get',
#   'well',
#   'faster',
#   'see',
#   'believe',
#   'sick',
#   'one',
#   'physician',
#   'high',
#   'standing',
#   'one',
#   'husband',
#   'assures',
#   'friend',
#   'relative',
#   'really',
#   'nothing',
#   'matter',
#   'one',
#   'temporary',
#   'nervous',
#   'depressiona',
#   'slight',
#   'hysterical',
#   'tendencywhat',
#   'one',
#   'brother',
#   'also',
#   'physician',
#   'also',
#   'high',
#   'standing',
#   'say',
#   'thing',
#   'take',
#   'phosphate',
#   'phosphiteswhichever',
#   'tonic',
#   'journey',
#   'air',
#   'exercise',
#   'absolutely',
#   'forbidden',
#   'work',
#   'well',
#   'personally',
#   'disagree',
#   'idea',
#   'personally',
#   'believe',
#   'congenial',
#   'work',
#   'excitement',
#   'change',
#   'would',
#   'good',
#   'one',
#   'write',
#   'spite',
#   'exhaust',
#   'good',
#   'dealhaving',
#   'sly',
#   'else',
#   'meet',
#   'heavy',
#   'opposition',
#   'sometimes',
#   'fancy',
#   'condition',
#   'le',
#   'opposition',
#   'society',
#   'stimulusbut',
#   'john',
#   'say',
#   'worst',
#   'thing',
#   'think',
#   'condition',
#   'confess',
#   'always',
#   'make',
#   'feel',
#   'bad',
#   'let',
#   'alone',
#   'talk',
#   'house',
#   'beautiful',
#   'place',
#   'quite',
#   'alone',
#   'standing',
#   'well',
#   'back',
#   'road',
#   'quite',
#   'three',
#   'mile',
#   'village',
#   'make',
#   'think',
#   'english',
#   'place',
#   'read',
#   'hedge',
#   'wall',
#   'gate',
#   'lock',
#   'lot',
#   'separate',
#   'little',
#   'house',
#   'gardener',
#   'people',
#   'delicious',
#   'garden',
#   'never',
#   'saw',
#   'gardenlarge',
#   'shady',
#   'full',
#   'boxbordered',
#   'path',
#   'lined',
#   'long',
#   'grapecovered',
#   'arbor',
#   'seat',
#   'greenhouse',
#   'broken',
#   'legal',
#   'trouble',
#   'believe',
#   'something',
#   'heir',
#   'coheirs',
#   'anyhow',
#   'place',
#   'empty',
#   'year',
#   'spoil',
#   'ghostliness',
#   'afraid',
#   'dont',
#   'carethere',
#   'something',
#   'strange',
#   'housei',
#   'feel',
#   'even',
#   'said',
#   'john',
#   'one',
#   'moonlight',
#   'evening',
#   'said',
#   'felt',
#   'draught',
#   'shut',
#   'window',
#   'get',
#   'unreasonably',
#   'angry',
#   'john',
#   'sometimes',
#   'im',
#   'sure',
#   'never',
#   'used',
#   'sensitive',
#   'think',
#   'due',
#   'nervous',
#   'condition',
#   'john',
#   'say',
#   'feel',
#   'shall',
#   'neglect',
#   'proper',
#   'selfcontrol',
#   'take',
#   'pain',
#   'control',
#   'myselfbefore',
#   'leastand',
#   'make',
#   'tired',
#   'dont',
#   'like',
#   'room',
#   'bit',
#   'wanted',
#   'one',
#   'downstairs',
#   'opened',
#   'piazza',
#   'rose',
#   'window',
#   'pretty',
#   'oldfashioned',
#   'chintz',
#   'hanging',
#   'john',
#   'would',
#   'hear',
#   'said',
#   'one',
#   'window',
#   'room',
#   'two',
#   'bed',
#   'near',
#   'room',
#   'took',
#   'another',
#   'careful',
#   'loving',
#   'hardly',
#   'let',
#   'stir',
#   'without',
#   'special',
#   'direction',
#   'schedule',
#   'prescription',
#   'hour',
#   'day',
#   'take',
#   'care',
#   'feel',
#   'basely',
#   'ungrateful',
#   'value',
#   'said',
#   'came',
#   'solely',
#   'account',
#   'perfect',
#   'rest',
#   'air',
#   'could',
#   'get',
#   'exercise',
#   'depends',
#   'strength',
#   'dear',
#   'said',
#   'food',
#   'somewhat',
#   'appetite',
#   'air',
#   'absorb',
#   'time',
#   'took',
#   'nursery',
#   'top',
#   'house',
#   'big',
#   'airy',
#   'room',
#   'whole',
#   'floor',
#   'nearly',
#   'window',
#   'look',
#   'way',
#   'air',
#   'sunshine',
#   'galore',
#   'nursery',
#   'first',
#   'playground',
#   'gymnasium',
#   'judge',
#   'window',
#   'barred',
#   'little',
#   'child',
#   'ring',
#   'thing',
#   'wall',
#   'paint',
#   'paper',
#   'look',
#   'boy',
#   'school',
#   'used',
#   'stripped',
#   'offthe',
#   'paperin',
#   'great',
#   'patch',
#   'around',
#   'head',
#   'bed',
#   'far',
#   'reach',
#   'great',
#   'place',
#   'side',
#   'room',
#   'low',
#   'never',
#   'saw',
#   'worse',
#   'paper',
#   'life',
#   'one',
#   'sprawling',
#   'flamboyant',
#   'pattern',
#   'committing',
#   'every',
#   'artistic',
#   'sin',
#   'dull',
#   'enough',
#   'confuse',
#   'eye',
#   'following',
#   'pronounced',
#   'enough',
#   'constantly',
#   'irritate',
#   'provoke',
#   'study',
#   'follow',
#   'lame',
#   'uncertain',
#   'curve',
#   'little',
#   'distance',
#   'suddenly',
#   'commit',
#   'suicideplunge',
#   'outrageous',
#   'angle',
#   'destroy',
#   'unheardof',
#   'contradiction',
#   'color',
#   'repellant',
#   'almost',
#   'revolting',
#   'smouldering',
#   'unclean',
#   'yellow',
#   'strangely',
#   'faded',
#   'slowturning',
#   'sunlight',
#   'dull',
#   'yet',
#   'lurid',
#   'orange',
#   'place',
#   'sickly',
#   'sulphur',
#   'tint',
#   'others',
#   'wonder',
#   'child',
#   'hated',
#   'hate',
#   'live',
#   'room',
#   'long',
#   'come',
#   'john',
#   'must',
#   'put',
#   'awayhe',
#   'hate',
#   'write',
#   'word',
#   'two',
#   'week',
#   'havent',
#   'felt',
#   'like',
#   'writing',
#   'since',
#   'first',
#   'day',
#   'sitting',
#   'window',
#   'atrocious',
#   'nursery',
#   'nothing',
#   'hinder',
#   'writing',
#   'much',
#   'please',
#   'save',
#   'lack',
#   'strength',
#   'john',
#   'away',
#   'day',
#   'even',
#   'night',
#   'case',
#   'serious',
#   'glad',
#   'case',
#   'serious',
#   'nervous',
#   'trouble',
#   'dreadfully',
#   'depressing',
#   'john',
#   'know',
#   'much',
#   'really',
#   'suffer',
#   'know',
#   'reason',
#   'suffer',
#   'satisfies',
#   'course',
#   'nervousness',
#   'weigh',
#   'duty',
#   'way',
#   'meant',
#   'help',
#   'john',
#   'real',
#   'rest',
#   'comfort',
#   'comparative',
#   'burden',
#   'already',
#   'nobody',
#   'would',
#   'believe',
#   'effort',
#   'little',
#   'ableto',
#   'dress',
#   'entertain',
#   'order',
#   'thing',
#   'fortunate',
#   'mary',
#   'good',
#   'baby',
#   'dear',
#   'baby',
#   'yet',
#   'make',
#   'nervous',
#   'suppose',
#   'john',
#   'never',
#   'nervous',
#   'life',
#   'laugh',
#   'wallpaper',
#   'first',
#   'meant',
#   'repaper',
#   'room',
#   'afterwards',
#   'said',
#   'letting',
#   'get',
#   'better',
#   'nothing',
#   'worse',
#   'nervous',
#   'patient',
#   'give',
#   'way',
#   'fancy',
#   'said',
#   'wallpaper',
#   'changed',
#   'would',
#   'heavy',
#   'bedstead',
#   'barred',
#   'window',
#   'gate',
#   'head',
#   'stair',
#   'know',
#   'place',
#   'good',
#   'said',
#   'really',
#   'dear',
#   'dont',
#   'care',
#   'renovate',
#   'house',
#   'three',
#   'month',
#   'rental',
#   'let',
#   'u',
#   'go',
#   'downstairs',
#   'said',
#   'pretty',
#   'room',
#   'took',
#   'arm',
#   'called',
#   'blessed',
#   'little',
#   'goose',
#   'said',
#   'would',
#   'go',
#   'cellar',
#   'wished',
#   'whitewashed',
#   'bargain',
#   'right',
#   'enough',
#   'bed',
#   'window',
#   'thing',
#   'airy',
#   'comfortable',
#   'room',
#   'one',
#   'need',
#   'wish',
#   'course',
#   'would',
#   'silly',
#   'make',
#   'uncomfortable',
#   'whim',
#   'im',
#   'really',
#   'getting',
#   'quite',
#   'fond',
#   'big',
#   'room',
#   'horrid',
#   'paper',
#   'one',
#   'window',
#   'see',
#   'garden',
#   'mysterious',
#   'deepshaded',
#   'arbor',
#   'riotous',
#   'oldfashioned',
#   'flower',
#   'bush',
#   'gnarly',
#   'tree',
#   'another',
#   'get',
#   'lovely',
#   'view',
#   'bay',
#   'little',
#   'private',
#   'wharf',
#   'belonging',
#   'estate',
#   'beautiful',
#   'shaded',
#   'lane',
#   'run',
#   'house',
#   'always',
#   'fancy',
#   'see',
#   'people',
#   'walking',
#   'numerous',
#   'path',
#   'arbor',
#   'john',
#   'cautioned',
#   'give',
#   'way',
#   'fancy',
#   'least',
#   'say',
#   'imaginative',
#   'power',
#   'habit',
#   'storymaking',
#   'nervous',
#   'weakness',
#   'like',
#   'mine',
#   'sure',
#   'lead',
#   'manner',
#   'excited',
#   'fancy',
#   'ought',
#   'use',
#   'good',
#   'sense',
#   'check',
#   'tendency',
#   'try',
#   'think',
#   'sometimes',
#   'well',
#   'enough',
#   'write',
#   'little',
#   'would',
#   'relieve',
#   'press',
#   'idea',
#   'rest',
#   'find',
#   'get',
#   'pretty',
#   'tired',
#   'try',
#   'discouraging',
#   'advice',
#   'companionship',
#   'work',
#   'get',
#   'really',
#   'well',
#   'john',
#   'say',
#   'ask',
#   'cousin',
#   'henry',
#   'julia',
#   'long',
#   'visit',
#   'say',
#   'would',
#   'soon',
#   'put',
#   'firework',
#   'pillowcase',
#   'let',
#   'stimulating',
#   'people',
#   'wish',
#   'could',
#   'get',
#   'well',
#   'faster',
#   'must',
#   'think',
#   'paper',
#   'look',
#   'knew',
#   'vicious',
#   'influence',
#   'recurrent',
#   'spot',
#   'pattern',
#   'lolls',
#   'like',
#   'broken',
#   'neck',
#   'two',
#   'bulbous',
#   'eye',
#   'stare',
#   'upsidedown',
#   'get',
#   'positively',
#   'angry',
#   'impertinence',
#   'everlastingness',
#   'sideways',
#   'crawl',
#   'absurd',
#   'unblinking',
#   'eye',
#   'everywhere',
#   'one',
#   'place',
#   'two',
#   'breadth',
#   'didnt',
#   'match',
#   'eye',
#   'go',
#   'line',
#   'one',
#   'little',
#   'higher',
#   'never',
#   'saw',
#   'much',
#   'expression',
#   'inanimate',
#   'thing',
#   'know',
#   'much',
#   'expression',
#   'used',
#   'lie',
#   'awake',
#   'child',
#   'get',
#   'entertainment',
#   'terror',
#   'blank',
#   'wall',
#   'plain',
#   'furniture',
#   'child',
#   'could',
#   'find',
#   'toystore',
#   'remember',
#   'kindly',
#   'wink',
#   'knob',
#   'big',
#   'old',
#   'bureau',
#   'used',
#   'one',
#   'chair',
#   'always',
#   'seemed',
#   'like',
#   'strong',
#   'friend',
#   'used',
#   'feel',
#   'thing',
#   'looked',
#   'fierce',
#   'could',
#   'always',
#   'hop',
#   'chair',
#   'safe',
#   'furniture',
#   'room',
#   'worse',
#   'inharmonious',
#   'however',
#   'bring',
#   'downstairs',
#   'suppose',
#   'used',
#   'playroom',
#   'take',
#   'nursery',
#   'thing',
#   'wonder',
#   'never',
#   'saw',
#   'ravage',
#   'child',
#   'made',
#   'wallpaper',
#   'said',
#   'torn',
#   'spot',
#   'sticketh',
#   'closer',
#   'brotherthey',
#   'must',
#   'perseverance',
#   'well',
#   'hatred',
#   'floor',
#   'scratched',
#   'gouged',
#   'splintered',
#   'plaster',
#   'dug',
#   'great',
#   'heavy',
#   'bed',
#   'found',
#   'room',
#   'look',
#   'war',
#   'dont',
#   'mind',
#   'bitonly',
#   'paper',
#   'come',
#   'john',
#   'sister',
#   'dear',
#   'girl',
#   'careful',
#   'must',
#   'let',
#   'find',
#   'writing',
#   'perfect',
#   'enthusiastic',
#   'housekeeper',
#   'hope',
#   'better',
#   'profession',
#   'verily',
#   'believe',
#   'think',
#   'writing',
#   'made',
#   'sick',
#   'write',
#   'see',
#   'long',
#   'way',
#   'window',
#   'one',
#   'command',
#   'road',
#   'lovely',
#   'shaded',
#   'winding',
#   'road',
#   'one',
#   'look',
#   'country',
#   'lovely',
#   'country',
#   'full',
#   'great',
#   'elm',
#   'velvet',
#   'meadow',
#   'wallpaper',
#   'kind',
#   'subpattern',
#   'different',
#   'shade',
#   'particularly',
#   'irritating',
#   'one',
#   'see',
#   'certain',
#   'light',
#   'clearly',
#   'place',
#   'isnt',
#   'faded',
#   'sun',
#   'see',
#   ...],
#  ['project',
#   'gutenberg',
#   'ebook',
#   'christmas',
#   'carol',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'christmas',
#   'carol',
#   'author',
#   'charles',
#   'dickens',
#   'illustrator',
#   'arthur',
#   'rackham',
#   'release',
#   'date',
#   'december',
#   'ebook',
#   'language',
#   'english',
#   'original',
#   'publication',
#   'philadelphia',
#   'new',
#   'york',
#   'j',
#   'b',
#   'lippincott',
#   'company',
#   'credit',
#   'produced',
#   'suzanne',
#   'shell',
#   'janet',
#   'blenkinship',
#   'online',
#   'distributed',
#   'proofreading',
#   'team',
#   'httpwwwpgdpnet',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'christmas',
#   'carol',
#   'produced',
#   'suzanne',
#   'shell',
#   'janet',
#   'blenkinship',
#   'online',
#   'distributed',
#   'proofreading',
#   'team',
#   'httpwwwpgdpnet',
#   'christmas',
#   'carol',
#   'illustration',
#   'said',
#   'scrooge',
#   'caustic',
#   'cold',
#   'ever',
#   'want',
#   'christmas',
#   'carol',
#   'illustration',
#   'charles',
#   'dickens',
#   'illustration',
#   'illustrated',
#   'arthur',
#   'rackham',
#   'illustration',
#   'j',
#   'b',
#   'lippincott',
#   'company',
#   'philadelphia',
#   'new',
#   'york',
#   'first',
#   'published',
#   'reprinted',
#   'isbn',
#   'printed',
#   'great',
#   'britain',
#   'preface',
#   'endeavoured',
#   'ghostly',
#   'little',
#   'book',
#   'raise',
#   'ghost',
#   'idea',
#   'shall',
#   'put',
#   'reader',
#   'humour',
#   'season',
#   'may',
#   'haunt',
#   'house',
#   'pleasantly',
#   'one',
#   'wish',
#   'lay',
#   'faithful',
#   'friend',
#   'servant',
#   'c',
#   'december',
#   'character',
#   'bob',
#   'cratchit',
#   'clerk',
#   'ebenezer',
#   'scrooge',
#   'peter',
#   'cratchit',
#   'son',
#   'preceding',
#   'tim',
#   'cratchit',
#   'tiny',
#   'tim',
#   'cripple',
#   'youngest',
#   'son',
#   'bob',
#   'cratchit',
#   'mr',
#   'fezziwig',
#   'kindhearted',
#   'jovial',
#   'old',
#   'merchant',
#   'fred',
#   'scrooge',
#   'nephew',
#   'ghost',
#   'christmas',
#   'past',
#   'phantom',
#   'showing',
#   'thing',
#   'past',
#   'ghost',
#   'christmas',
#   'present',
#   'spirit',
#   'kind',
#   'generous',
#   'hearty',
#   'nature',
#   'ghost',
#   'christmas',
#   'yet',
#   'come',
#   'apparition',
#   'showing',
#   'shadow',
#   'thing',
#   'yet',
#   'may',
#   'happen',
#   'ghost',
#   'jacob',
#   'marley',
#   'spectre',
#   'scrooge',
#   'former',
#   'partner',
#   'business',
#   'joe',
#   'marinestore',
#   'dealer',
#   'receiver',
#   'stolen',
#   'good',
#   'ebenezer',
#   'scrooge',
#   'grasping',
#   'covetous',
#   'old',
#   'man',
#   'surviving',
#   'partner',
#   'firm',
#   'scrooge',
#   'marley',
#   'mr',
#   'topper',
#   'bachelor',
#   'dick',
#   'wilkins',
#   'fellow',
#   'apprentice',
#   'scrooge',
#   'belle',
#   'comely',
#   'matron',
#   'old',
#   'sweetheart',
#   'scrooge',
#   'caroline',
#   'wife',
#   'one',
#   'scrooge',
#   'debtor',
#   'mr',
#   'cratchit',
#   'wife',
#   'bob',
#   'cratchit',
#   'belinda',
#   'martha',
#   'cratchit',
#   'daughter',
#   'preceding',
#   'mr',
#   'dilber',
#   'laundress',
#   'fan',
#   'sister',
#   'scrooge',
#   'mr',
#   'fezziwig',
#   'worthy',
#   'partner',
#   'mr',
#   'fezziwig',
#   'content',
#   'stave',
#   'onemarleys',
#   'ghost',
#   'stave',
#   'twothe',
#   'first',
#   'three',
#   'spirit',
#   'stave',
#   'threethe',
#   'second',
#   'three',
#   'spirit',
#   'stave',
#   'fourthe',
#   'last',
#   'spirit',
#   'stave',
#   'fivethe',
#   'end',
#   'list',
#   'illustration',
#   'colour',
#   'said',
#   'scrooge',
#   'caustic',
#   'cold',
#   'ever',
#   'want',
#   'frontispiece',
#   'bob',
#   'cratchit',
#   'went',
#   'slide',
#   'cornhill',
#   'end',
#   'lane',
#   'boy',
#   'twenty',
#   'time',
#   'honour',
#   'christmas',
#   'eve',
#   'nobody',
#   'bed',
#   'nobody',
#   'closet',
#   'nobody',
#   'dressinggown',
#   'hanging',
#   'suspicious',
#   'attitude',
#   'wall',
#   'air',
#   'filled',
#   'phantom',
#   'wandering',
#   'hither',
#   'thither',
#   'restless',
#   'haste',
#   'moaning',
#   'went',
#   'old',
#   'fezziwig',
#   'stood',
#   'dance',
#   'mr',
#   'fezziwig',
#   'flushed',
#   'boisterous',
#   'group',
#   'laden',
#   'christmas',
#   'toy',
#   'present',
#   'way',
#   'went',
#   'plump',
#   'sister',
#   'lace',
#   'tucker',
#   'said',
#   'one',
#   'returned',
#   'well',
#   'said',
#   'first',
#   'old',
#   'scratch',
#   'got',
#   'last',
#   'hey',
#   'call',
#   'said',
#   'joe',
#   'bedcurtains',
#   'ah',
#   'returned',
#   'woman',
#   'laughing',
#   'bedcurtains',
#   'dont',
#   'mean',
#   'say',
#   'took',
#   'em',
#   'ring',
#   'lying',
#   'said',
#   'joe',
#   'yes',
#   'replied',
#   'woman',
#   'uncle',
#   'scrooge',
#   'come',
#   'dinner',
#   'let',
#   'fred',
#   'ill',
#   'tell',
#   'friend',
#   'said',
#   'scrooge',
#   'going',
#   'stand',
#   'sort',
#   'thing',
#   'longer',
#   'illustration',
#   'black',
#   'white',
#   'tailpiece',
#   'vi',
#   'tailpiece',
#   'list',
#   'coloured',
#   'illustration',
#   'x',
#   'tailpiece',
#   'list',
#   'black',
#   'white',
#   'illustration',
#   'xi',
#   'heading',
#   'stave',
#   'one',
#   'portly',
#   'gentleman',
#   'pleasant',
#   'behold',
#   'wing',
#   'wind',
#   'tailpiece',
#   'stave',
#   'one',
#   'heading',
#   'stave',
#   'two',
#   'produced',
#   'decanter',
#   'curiously',
#   'light',
#   'wine',
#   'block',
#   'curiously',
#   'heavy',
#   'cake',
#   'left',
#   'parted',
#   'tailpiece',
#   'stave',
#   'two',
#   'heading',
#   'stave',
#   'three',
#   'nothing',
#   'cheerful',
#   'climate',
#   'tims',
#   'bloodhorse',
#   'way',
#   'church',
#   'pudding',
#   'heading',
#   'stave',
#   'four',
#   'heading',
#   'stave',
#   'five',
#   'tailpiece',
#   'stave',
#   'five',
#   'illustration',
#   'stave',
#   'one',
#   'illustration',
#   'marley',
#   'ghost',
#   'marley',
#   'dead',
#   'begin',
#   'doubt',
#   'whatever',
#   'register',
#   'burial',
#   'signed',
#   'clergyman',
#   'clerk',
#   'undertaker',
#   'chief',
#   'mourner',
#   'scrooge',
#   'signed',
#   'scrooge',
#   'name',
#   'good',
#   'upon',
#   'change',
#   'anything',
#   'chose',
#   'put',
#   'hand',
#   'old',
#   'marley',
#   'dead',
#   'doornail',
#   'mind',
#   'dont',
#   'mean',
#   'say',
#   'know',
#   'knowledge',
#   'particularly',
#   'dead',
#   'doornail',
#   'might',
#   'inclined',
#   'regard',
#   'coffinnail',
#   'deadest',
#   'piece',
#   'ironmongery',
#   'trade',
#   'wisdom',
#   'ancestor',
#   'simile',
#   'unhallowed',
#   'hand',
#   'shall',
#   'disturb',
#   'country',
#   'done',
#   'therefore',
#   'permit',
#   'repeat',
#   'emphatically',
#   'marley',
#   'dead',
#   'doornail',
#   'scrooge',
#   'knew',
#   'dead',
#   'course',
#   'could',
#   'otherwise',
#   'scrooge',
#   'partner',
#   'dont',
#   'know',
#   'many',
#   'year',
#   'scrooge',
#   'sole',
#   'executor',
#   'sole',
#   'administrator',
#   'sole',
#   'assign',
#   'sole',
#   'residuary',
#   'legatee',
#   'sole',
#   'friend',
#   'sole',
#   'mourner',
#   'even',
#   'scrooge',
#   'dreadfully',
#   'cut',
#   'sad',
#   'event',
#   'excellent',
#   'man',
#   'business',
#   'day',
#   'funeral',
#   'solemnised',
#   'undoubted',
#   'bargain',
#   'mention',
#   'marley',
#   'funeral',
#   'brings',
#   'back',
#   'point',
#   'started',
#   'doubt',
#   'marley',
#   'dead',
#   'must',
#   'distinctly',
#   'understood',
#   'nothing',
#   'wonderful',
#   'come',
#   'story',
#   'going',
#   'relate',
#   'perfectly',
#   'convinced',
#   'hamlet',
#   'father',
#   'died',
#   'play',
#   'began',
#   'would',
#   'nothing',
#   'remarkable',
#   'taking',
#   'stroll',
#   'night',
#   'easterly',
#   'wind',
#   'upon',
#   'rampart',
#   'would',
#   'middleaged',
#   'gentleman',
#   'rashly',
#   'turning',
#   'dark',
#   'breezy',
#   'spotsay',
#   'st',
#   'paul',
#   'churchyard',
#   'instanceliterally',
#   'astonish',
#   'son',
#   'weak',
#   'mind',
#   'scrooge',
#   'never',
#   'painted',
#   'old',
#   'marley',
#   'name',
#   'stood',
#   'year',
#   'afterwards',
#   'warehouse',
#   'door',
#   'scrooge',
#   'marley',
#   'firm',
#   'known',
#   'scrooge',
#   'marley',
#   'sometimes',
#   'people',
#   'new',
#   'business',
#   'called',
#   'scrooge',
#   'scrooge',
#   'sometimes',
#   'marley',
#   'answered',
#   'name',
#   'oh',
#   'tightfisted',
#   'hand',
#   'grindstone',
#   'scrooge',
#   'squeezing',
#   'wrenching',
#   'grasping',
#   'scraping',
#   'clutching',
#   'covetous',
#   'old',
#   'sinner',
#   'hard',
#   'sharp',
#   'flint',
#   'steel',
#   'ever',
#   'struck',
#   'generous',
#   'fire',
#   'secret',
#   'selfcontained',
#   'solitary',
#   'oyster',
#   'cold',
#   'within',
#   'froze',
#   'old',
#   'feature',
#   'nipped',
#   'pointed',
#   'nose',
#   'shrivelled',
#   'cheek',
#   'stiffened',
#   'gait',
#   'made',
#   'eye',
#   'red',
#   'thin',
#   'lip',
#   'blue',
#   'spoke',
#   'shrewdly',
#   'grating',
#   'voice',
#   'frosty',
#   'rime',
#   'head',
#   'eyebrow',
#   'wiry',
#   'chin',
#   'carried',
#   'low',
#   'temperature',
#   'always',
#   'iced',
#   'office',
#   'dogdays',
#   'didnt',
#   'thaw',
#   'one',
#   'degree',
#   'christmas',
#   'external',
#   'heat',
#   'cold',
#   'little',
#   'influence',
#   'scrooge',
#   'warmth',
#   'could',
#   'warm',
#   'wintry',
#   'weather',
#   'chill',
#   'wind',
#   'blew',
#   'bitterer',
#   'falling',
#   'snow',
#   'intent',
#   'upon',
#   'purpose',
#   'pelting',
#   'rain',
#   'le',
#   'open',
#   'entreaty',
#   'foul',
#   'weather',
#   'didnt',
#   'know',
#   'heaviest',
#   'rain',
#   'snow',
#   'hail',
#   'sleet',
#   'could',
#   'boast',
#   'advantage',
#   'one',
#   'respect',
#   'often',
#   'came',
#   'handsomely',
#   'scrooge',
#   'never',
#   'nobody',
#   'ever',
#   'stopped',
#   'street',
#   'say',
#   'gladsome',
#   'look',
#   'dear',
#   'scrooge',
#   'come',
#   'see',
#   'beggar',
#   'implored',
#   'bestow',
#   'trifle',
#   'child',
#   'asked',
#   'oclock',
#   'man',
#   'woman',
#   'ever',
#   'life',
#   'inquired',
#   'way',
#   'place',
#   'scrooge',
#   'even',
#   'blind',
#   'men',
#   'dog',
#   'appeared',
#   'know',
#   'saw',
#   'coming',
#   'would',
#   'tug',
#   'owner',
#   'doorway',
#   'court',
#   'would',
#   'wag',
#   'tail',
#   'though',
#   'said',
#   'eye',
#   'better',
#   'evil',
#   'eye',
#   'dark',
#   'master',
#   'scrooge',
#   'care',
#   'thing',
#   'liked',
#   'edge',
#   'way',
#   'along',
#   'crowded',
#   'path',
#   'life',
#   'warning',
#   'human',
#   'sympathy',
#   'keep',
#   'distance',
#   'knowing',
#   'one',
#   'call',
#   'nut',
#   'scrooge',
#   'upon',
#   'timeof',
#   'good',
#   'day',
#   'year',
#   'christmas',
#   'eveold',
#   'scrooge',
#   'sat',
#   'busy',
#   'countinghouse',
#   'cold',
#   'bleak',
#   'biting',
#   'weather',
#   'foggy',
#   'withal',
#   'could',
#   'hear',
#   'people',
#   'court',
#   'outside',
#   'go',
#   'wheezing',
#   'beating',
#   'hand',
#   'upon',
#   'breast',
#   'stamping',
#   'foot',
#   'upon',
#   'pavement',
#   'stone',
#   'warm',
#   'city',
#   'clock',
#   'gone',
#   'three',
#   'quite',
#   'dark',
#   'alreadyit',
#   'light',
#   'dayand',
#   'candle',
#   'flaring',
#   'window',
#   'neighbouring',
#   'office',
#   'like',
#   'ruddy',
#   'smear',
#   'upon',
#   'palpable',
#   'brown',
#   'air',
#   'fog',
#   'came',
#   'pouring',
#   'every',
#   'chink',
#   'keyhole',
#   'dense',
#   'without',
#   'although',
#   'court',
#   'narrowest',
#   'house',
#   'opposite',
#   'mere',
#   'phantom',
#   'see',
#   'dingy',
#   'cloud',
#   'come',
#   'drooping',
#   'obscuring',
#   'everything',
#   'one',
#   'might',
#   'thought',
#   'nature',
#   'lived',
#   'hard',
#   'brewing',
#   'large',
#   'scale',
#   'door',
#   'scrooge',
#   'countinghouse',
#   'open',
#   'might',
#   'keep',
#   'eye',
#   'upon',
#   'clerk',
#   'dismal',
#   'little',
#   'cell',
#   'beyond',
#   'sort',
#   'tank',
#   'copying',
#   'letter',
#   'scrooge',
#   'small',
#   'fire',
#   'clerk',
#   'fire',
#   'much',
#   'smaller',
#   'looked',
#   'like',
#   'one',
#   'coal',
#   'couldnt',
#   'replenish',
#   'scrooge',
#   'kept',
#   'coalbox',
#   'room',
#   'surely',
#   'clerk',
#   'came',
#   'shovel',
#   'master',
#   'predicted',
#   'would',
#   'necessary',
#   'part',
#   'wherefore',
#   'clerk',
#   'put',
#   'white',
#   'comforter',
#   'tried',
#   'warm',
#   'candle',
#   'effort',
#   'man',
#   'strong',
#   'imagination',
#   'failed',
#   'merry',
#   'christmas',
#   'uncle',
#   'god',
#   'save',
#   'cried',
#   'cheerful',
#   'voice',
#   'voice',
#   'scrooge',
#   'nephew',
#   'came',
#   'upon',
#   'quickly',
#   'first',
#   'intimation',
#   'approach',
#   'bah',
#   'said',
#   'scrooge',
#   'humbug',
#   'heated',
#   'rapid',
#   'walking',
#   'fog',
#   'frost',
#   'nephew',
#   'scrooge',
#   ...],
#  ['project',
#   'gutenberg',
#   'ebook',
#   'romeo',
#   'juliet',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'romeo',
#   'juliet',
#   'author',
#   'william',
#   'shakespeare',
#   'release',
#   'date',
#   'november',
#   'ebook',
#   'recently',
#   'updated',
#   'june',
#   'language',
#   'english',
#   'credit',
#   'pg',
#   'shakespeare',
#   'team',
#   'team',
#   'twenty',
#   'project',
#   'gutenberg',
#   'volunteer',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'romeo',
#   'juliet',
#   'tragedy',
#   'romeo',
#   'juliet',
#   'william',
#   'shakespeare',
#   'content',
#   'prologue',
#   'act',
#   'scene',
#   'public',
#   'place',
#   'scene',
#   'ii',
#   'street',
#   'scene',
#   'iii',
#   'room',
#   'capulets',
#   'house',
#   'scene',
#   'iv',
#   'street',
#   'scene',
#   'v',
#   'hall',
#   'capulets',
#   'house',
#   'act',
#   'ii',
#   'chorus',
#   'scene',
#   'open',
#   'place',
#   'adjoining',
#   'capulets',
#   'garden',
#   'scene',
#   'ii',
#   'capulets',
#   'garden',
#   'scene',
#   'iii',
#   'friar',
#   'lawrence',
#   'cell',
#   'scene',
#   'iv',
#   'street',
#   'scene',
#   'v',
#   'capulets',
#   'garden',
#   'scene',
#   'vi',
#   'friar',
#   'lawrence',
#   'cell',
#   'act',
#   'iii',
#   'scene',
#   'public',
#   'place',
#   'scene',
#   'ii',
#   'room',
#   'capulets',
#   'house',
#   'scene',
#   'iii',
#   'friar',
#   'lawrence',
#   'cell',
#   'scene',
#   'iv',
#   'room',
#   'capulets',
#   'house',
#   'scene',
#   'v',
#   'open',
#   'gallery',
#   'juliets',
#   'chamber',
#   'overlooking',
#   'garden',
#   'act',
#   'iv',
#   'scene',
#   'friar',
#   'lawrence',
#   'cell',
#   'scene',
#   'ii',
#   'hall',
#   'capulets',
#   'house',
#   'scene',
#   'iii',
#   'juliets',
#   'chamber',
#   'scene',
#   'iv',
#   'hall',
#   'capulets',
#   'house',
#   'scene',
#   'v',
#   'juliets',
#   'chamber',
#   'juliet',
#   'bed',
#   'act',
#   'v',
#   'scene',
#   'mantua',
#   'street',
#   'scene',
#   'ii',
#   'friar',
#   'lawrence',
#   'cell',
#   'scene',
#   'iii',
#   'churchyard',
#   'monument',
#   'belonging',
#   'capulets',
#   'dramatis',
#   'person',
#   'escalus',
#   'prince',
#   'verona',
#   'mercutio',
#   'kinsman',
#   'prince',
#   'friend',
#   'romeo',
#   'paris',
#   'young',
#   'nobleman',
#   'kinsman',
#   'prince',
#   'page',
#   'paris',
#   'montague',
#   'head',
#   'veronese',
#   'family',
#   'feud',
#   'capulets',
#   'lady',
#   'montague',
#   'wife',
#   'montague',
#   'romeo',
#   'son',
#   'montague',
#   'benvolio',
#   'nephew',
#   'montague',
#   'friend',
#   'romeo',
#   'abram',
#   'servant',
#   'montague',
#   'balthasar',
#   'servant',
#   'romeo',
#   'capulet',
#   'head',
#   'veronese',
#   'family',
#   'feud',
#   'montagues',
#   'lady',
#   'capulet',
#   'wife',
#   'capulet',
#   'juliet',
#   'daughter',
#   'capulet',
#   'tybalt',
#   'nephew',
#   'lady',
#   'capulet',
#   'capulets',
#   'cousin',
#   'old',
#   'man',
#   'nurse',
#   'juliet',
#   'peter',
#   'servant',
#   'juliets',
#   'nurse',
#   'sampson',
#   'servant',
#   'capulet',
#   'gregory',
#   'servant',
#   'capulet',
#   'servant',
#   'friar',
#   'lawrence',
#   'franciscan',
#   'friar',
#   'john',
#   'order',
#   'apothecary',
#   'chorus',
#   'three',
#   'musician',
#   'officer',
#   'citizen',
#   'verona',
#   'several',
#   'men',
#   'woman',
#   'relation',
#   'house',
#   'masker',
#   'guard',
#   'watchman',
#   'attendant',
#   'scene',
#   'greater',
#   'part',
#   'play',
#   'verona',
#   'fifth',
#   'act',
#   'mantua',
#   'prologue',
#   'enter',
#   'chorus',
#   'chorus',
#   'two',
#   'household',
#   'alike',
#   'dignity',
#   'fair',
#   'verona',
#   'lay',
#   'scene',
#   'ancient',
#   'grudge',
#   'break',
#   'new',
#   'mutiny',
#   'civil',
#   'blood',
#   'make',
#   'civil',
#   'hand',
#   'unclean',
#   'forth',
#   'fatal',
#   'loin',
#   'two',
#   'foe',
#   'pair',
#   'starcrossd',
#   'lover',
#   'take',
#   'life',
#   'whose',
#   'misadventurd',
#   'piteous',
#   'overthrow',
#   'doth',
#   'death',
#   'bury',
#   'parent',
#   'strife',
#   'fearful',
#   'passage',
#   'deathmarkd',
#   'love',
#   'continuance',
#   'parent',
#   'rage',
#   'childrens',
#   'end',
#   'nought',
#   'could',
#   'remove',
#   'two',
#   'hour',
#   'traffic',
#   'stage',
#   'patient',
#   'ear',
#   'attend',
#   'shall',
#   'miss',
#   'toil',
#   'shall',
#   'strive',
#   'mend',
#   'exit',
#   'act',
#   'scene',
#   'public',
#   'place',
#   'enter',
#   'sampson',
#   'gregory',
#   'armed',
#   'sword',
#   'buckler',
#   'sampson',
#   'gregory',
#   'word',
#   'well',
#   'carry',
#   'coal',
#   'gregory',
#   'collier',
#   'sampson',
#   'mean',
#   'choler',
#   'well',
#   'draw',
#   'gregory',
#   'ay',
#   'live',
#   'draw',
#   'neck',
#   'collar',
#   'sampson',
#   'strike',
#   'quickly',
#   'moved',
#   'gregory',
#   'thou',
#   'art',
#   'quickly',
#   'moved',
#   'strike',
#   'sampson',
#   'dog',
#   'house',
#   'montague',
#   'move',
#   'gregory',
#   'move',
#   'stir',
#   'valiant',
#   'stand',
#   'therefore',
#   'thou',
#   'art',
#   'moved',
#   'thou',
#   'runnst',
#   'away',
#   'sampson',
#   'dog',
#   'house',
#   'shall',
#   'move',
#   'stand',
#   'take',
#   'wall',
#   'man',
#   'maid',
#   'montagues',
#   'gregory',
#   'show',
#   'thee',
#   'weak',
#   'slave',
#   'weakest',
#   'go',
#   'wall',
#   'sampson',
#   'true',
#   'therefore',
#   'woman',
#   'weaker',
#   'vessel',
#   'ever',
#   'thrust',
#   'wall',
#   'therefore',
#   'push',
#   'montagues',
#   'men',
#   'wall',
#   'thrust',
#   'maid',
#   'wall',
#   'gregory',
#   'quarrel',
#   'master',
#   'u',
#   'men',
#   'sampson',
#   'ti',
#   'one',
#   'show',
#   'tyrant',
#   'fought',
#   'men',
#   'civil',
#   'maid',
#   'cut',
#   'head',
#   'gregory',
#   'head',
#   'maid',
#   'sampson',
#   'ay',
#   'head',
#   'maid',
#   'maidenhead',
#   'take',
#   'sense',
#   'thou',
#   'wilt',
#   'gregory',
#   'must',
#   'take',
#   'sense',
#   'feel',
#   'sampson',
#   'shall',
#   'feel',
#   'able',
#   'stand',
#   'ti',
#   'known',
#   'pretty',
#   'piece',
#   'flesh',
#   'gregory',
#   'ti',
#   'well',
#   'thou',
#   'art',
#   'fish',
#   'thou',
#   'hadst',
#   'thou',
#   'hadst',
#   'poor',
#   'john',
#   'draw',
#   'thy',
#   'tool',
#   'come',
#   'house',
#   'montagues',
#   'enter',
#   'abram',
#   'balthasar',
#   'sampson',
#   'naked',
#   'weapon',
#   'quarrel',
#   'back',
#   'thee',
#   'gregory',
#   'turn',
#   'thy',
#   'back',
#   'run',
#   'sampson',
#   'fear',
#   'gregory',
#   'marry',
#   'fear',
#   'thee',
#   'sampson',
#   'let',
#   'u',
#   'take',
#   'law',
#   'side',
#   'let',
#   'begin',
#   'gregory',
#   'frown',
#   'pas',
#   'let',
#   'take',
#   'list',
#   'sampson',
#   'nay',
#   'dare',
#   'bite',
#   'thumb',
#   'disgrace',
#   'bear',
#   'abram',
#   'bite',
#   'thumb',
#   'u',
#   'sir',
#   'sampson',
#   'bite',
#   'thumb',
#   'sir',
#   'abram',
#   'bite',
#   'thumb',
#   'u',
#   'sir',
#   'sampson',
#   'law',
#   'side',
#   'say',
#   'ay',
#   'gregory',
#   'sampson',
#   'sir',
#   'bite',
#   'thumb',
#   'sir',
#   'bite',
#   'thumb',
#   'sir',
#   'gregory',
#   'quarrel',
#   'sir',
#   'abram',
#   'quarrel',
#   'sir',
#   'sir',
#   'sampson',
#   'sir',
#   'serve',
#   'good',
#   'man',
#   'abram',
#   'better',
#   'sampson',
#   'well',
#   'sir',
#   'enter',
#   'benvolio',
#   'gregory',
#   'say',
#   'better',
#   'come',
#   'one',
#   'master',
#   'kinsman',
#   'sampson',
#   'yes',
#   'better',
#   'sir',
#   'abram',
#   'lie',
#   'sampson',
#   'draw',
#   'men',
#   'gregory',
#   'remember',
#   'thy',
#   'washing',
#   'blow',
#   'fight',
#   'benvolio',
#   'part',
#   'fool',
#   'put',
#   'sword',
#   'know',
#   'beat',
#   'sword',
#   'enter',
#   'tybalt',
#   'tybalt',
#   'art',
#   'thou',
#   'drawn',
#   'among',
#   'heartless',
#   'hind',
#   'turn',
#   'thee',
#   'benvolio',
#   'look',
#   'upon',
#   'thy',
#   'death',
#   'benvolio',
#   'keep',
#   'peace',
#   'put',
#   'thy',
#   'sword',
#   'manage',
#   'part',
#   'men',
#   'tybalt',
#   'drawn',
#   'talk',
#   'peace',
#   'hate',
#   'word',
#   'hate',
#   'hell',
#   'montagues',
#   'thee',
#   'thee',
#   'coward',
#   'fight',
#   'enter',
#   'three',
#   'four',
#   'citizen',
#   'club',
#   'first',
#   'citizen',
#   'club',
#   'bill',
#   'partisan',
#   'strike',
#   'beat',
#   'capulets',
#   'montagues',
#   'enter',
#   'capulet',
#   'gown',
#   'lady',
#   'capulet',
#   'capulet',
#   'noise',
#   'give',
#   'long',
#   'sword',
#   'ho',
#   'lady',
#   'capulet',
#   'crutch',
#   'crutch',
#   'call',
#   'sword',
#   'capulet',
#   'sword',
#   'say',
#   'old',
#   'montague',
#   'come',
#   'flourish',
#   'blade',
#   'spite',
#   'enter',
#   'montague',
#   'lady',
#   'montague',
#   'montague',
#   'thou',
#   'villain',
#   'capulet',
#   'hold',
#   'let',
#   'go',
#   'lady',
#   'montague',
#   'thou',
#   'shalt',
#   'stir',
#   'one',
#   'foot',
#   'seek',
#   'foe',
#   'enter',
#   'prince',
#   'escalus',
#   'attendant',
#   'prince',
#   'rebellious',
#   'subject',
#   'enemy',
#   'peace',
#   'profaners',
#   'neighbourstained',
#   'steel',
#   'hear',
#   'ho',
#   'men',
#   'beast',
#   'quench',
#   'fire',
#   'pernicious',
#   'rage',
#   'purple',
#   'fountain',
#   'issuing',
#   'vein',
#   'pain',
#   'torture',
#   'bloody',
#   'hand',
#   'throw',
#   'mistemperd',
#   'weapon',
#   'ground',
#   'hear',
#   'sentence',
#   'moved',
#   'prince',
#   'three',
#   'civil',
#   'brawl',
#   'bred',
#   'airy',
#   'word',
#   'thee',
#   'old',
#   'capulet',
#   'montague',
#   'thrice',
#   'disturbd',
#   'quiet',
#   'street',
#   'made',
#   'verona',
#   'ancient',
#   'citizen',
#   'cast',
#   'grave',
#   'beseeming',
#   'ornament',
#   'wield',
#   'old',
#   'partisan',
#   'hand',
#   'old',
#   'cankerd',
#   'peace',
#   'part',
#   'cankerd',
#   'hate',
#   'ever',
#   'disturb',
#   'street',
#   'life',
#   'shall',
#   'pay',
#   'forfeit',
#   'peace',
#   'time',
#   'rest',
#   'depart',
#   'away',
#   'capulet',
#   'shall',
#   'go',
#   'along',
#   'montague',
#   'come',
#   'afternoon',
#   'know',
#   'farther',
#   'pleasure',
#   'case',
#   'old',
#   'freetown',
#   'common',
#   'judgementplace',
#   'pain',
#   'death',
#   'men',
#   'depart',
#   'exeunt',
#   'prince',
#   'attendant',
#   'capulet',
#   'lady',
#   'capulet',
#   'tybalt',
#   'citizen',
#   'servant',
#   'montague',
#   'set',
#   'ancient',
#   'quarrel',
#   'new',
#   'abroach',
#   'speak',
#   'nephew',
#   'began',
#   'benvolio',
#   'servant',
#   'adversary',
#   'close',
#   'fighting',
#   'ere',
#   'approach',
#   'drew',
#   'part',
#   'instant',
#   'came',
#   'fiery',
#   'tybalt',
#   'sword',
#   'prepard',
#   'breathd',
#   'defiance',
#   'ear',
#   'swung',
#   'head',
#   'cut',
#   'wind',
#   'nothing',
#   'hurt',
#   'withal',
#   'hissd',
#   'scorn',
#   'interchanging',
#   'thrust',
#   'blow',
#   'came',
#   'fought',
#   'part',
#   'part',
#   'till',
#   'prince',
#   'came',
#   'parted',
#   'either',
#   'part',
#   'lady',
#   'montague',
#   'romeo',
#   'saw',
#   'today',
#   'right',
#   'glad',
#   'fray',
#   'benvolio',
#   'madam',
#   'hour',
#   'worshippd',
#   'sun',
#   'peerd',
#   'forth',
#   'golden',
#   'window',
#   'east',
#   'troubled',
#   'mind',
#   'drave',
#   'walk',
#   'abroad',
#   'underneath',
#   'grove',
#   'sycamore',
#   'westward',
#   'rooteth',
#   'city',
#   'side',
#   'early',
#   'walking',
#   'see',
#   'son',
#   'towards',
#   'made',
#   'ware',
#   'stole',
#   'covert',
#   'wood',
#   'measuring',
#   'affection',
#   'sought',
#   'might',
#   'found',
#   'one',
#   'many',
#   'weary',
#   'self',
#   'pursud',
#   'humour',
#   'pursuing',
#   'gladly',
#   'shunnd',
#   'gladly',
#   'fled',
#   'montague',
#   'many',
#   'morning',
#   'hath',
#   'seen',
#   'tear',
#   'augmenting',
#   'fresh',
#   'morning',
#   'dew',
#   'adding',
#   'cloud',
#   'cloud',
#   'deep',
#   'sigh',
#   'soon',
#   'allcheering',
#   'sun',
#   'farthest',
#   'east',
#   'begin',
#   'draw',
#   'shady',
#   'curtain',
#   'aurora',
#   'bed',
#   'away',
#   'light',
#   'steal',
#   'home',
#   'heavy',
#   'son',
#   'private',
#   'chamber',
#   'pen',
#   'shuts',
#   'window',
#   'lock',
#   'fair',
#   'daylight',
#   'make',
#   'artificial',
#   'night',
#   'black',
#   'portentous',
#   'must',
#   'humour',
#   'prove',
#   'unless',
#   ...],
#  ['project',
#   'gutenberg',
#   'ebook',
#   'winniethepooh',
#   'ebook',
#   'use',
#   'anyone',
#   'anywhere',
#   'united',
#   'state',
#   'part',
#   'world',
#   'cost',
#   'almost',
#   'restriction',
#   'whatsoever',
#   'may',
#   'copy',
#   'give',
#   'away',
#   'reuse',
#   'term',
#   'project',
#   'gutenberg',
#   'license',
#   'included',
#   'ebook',
#   'online',
#   'wwwgutenbergorg',
#   'located',
#   'united',
#   'state',
#   'check',
#   'law',
#   'country',
#   'located',
#   'using',
#   'ebook',
#   'title',
#   'winniethepooh',
#   'author',
#   'milne',
#   'illustrator',
#   'ernest',
#   'h',
#   'shepard',
#   'release',
#   'date',
#   'january',
#   'ebook',
#   'recently',
#   'updated',
#   'december',
#   'language',
#   'english',
#   'original',
#   'publication',
#   'canada',
#   'mcclelland',
#   'stewart',
#   'ltd',
#   'credit',
#   'greg',
#   'week',
#   'mary',
#   'meehan',
#   'iona',
#   'vaughan',
#   'david',
#   'jones',
#   'online',
#   'distributed',
#   'proofreader',
#   'canada',
#   'team',
#   'httpwwwpgdpcanadanet',
#   'start',
#   'project',
#   'gutenberg',
#   'ebook',
#   'winniethepooh',
#   'winniethepooh',
#   'milne',
#   'juvenile',
#   'young',
#   'best',
#   'book',
#   'verse',
#   'child',
#   'ever',
#   'writtena',
#   'edward',
#   'newton',
#   'atlantic',
#   'monthly',
#   'fourteen',
#   'song',
#   'young',
#   'word',
#   'milne',
#   'music',
#   'h',
#   'frasersimson',
#   'decoration',
#   'e',
#   'h',
#   'shepard',
#   'king',
#   'breakfast',
#   'word',
#   'milne',
#   'music',
#   'h',
#   'frasersimson',
#   'decoration',
#   'e',
#   'h',
#   'shepard',
#   'essay',
#   'matter',
#   'sunny',
#   'side',
#   'may',
#   'mystery',
#   'story',
#   'red',
#   'house',
#   'mystery',
#   'winniethepooh',
#   'milne',
#   'mcclelland',
#   'stewart',
#   'ltd',
#   'publisher',
#   'toronto',
#   'copyright',
#   'canada',
#   'mcclelland',
#   'stewart',
#   'limited',
#   'publisher',
#   'toronto',
#   'first',
#   'printing',
#   'october',
#   'second',
#   'july',
#   'third',
#   'december',
#   'fourth',
#   'december',
#   'fifth',
#   'march',
#   'printed',
#   'canada',
#   'hand',
#   'hand',
#   'come',
#   'christopher',
#   'robin',
#   'lay',
#   'book',
#   'lap',
#   'say',
#   'youre',
#   'surprised',
#   'say',
#   'like',
#   'say',
#   'wanted',
#   'love',
#   'introduction',
#   'happen',
#   'read',
#   'another',
#   'book',
#   'christopher',
#   'robin',
#   'may',
#   'remember',
#   'swan',
#   'swan',
#   'christopher',
#   'robin',
#   'dont',
#   'know',
#   'used',
#   'call',
#   'swan',
#   'pooh',
#   'long',
#   'time',
#   'ago',
#   'said',
#   'goodbye',
#   'took',
#   'name',
#   'u',
#   'didnt',
#   'think',
#   'swan',
#   'would',
#   'want',
#   'well',
#   'edward',
#   'bear',
#   'said',
#   'would',
#   'like',
#   'exciting',
#   'name',
#   'christopher',
#   'robin',
#   'said',
#   'without',
#   'stopping',
#   'think',
#   'winniethepooh',
#   'explained',
#   'pooh',
#   'part',
#   'explain',
#   'rest',
#   'cant',
#   'london',
#   'long',
#   'without',
#   'going',
#   'zoo',
#   'people',
#   'begin',
#   'zoo',
#   'beginning',
#   'called',
#   'wayin',
#   'walk',
#   'quickly',
#   'past',
#   'every',
#   'cage',
#   'get',
#   'one',
#   'called',
#   'wayout',
#   'nicest',
#   'people',
#   'go',
#   'straight',
#   'animal',
#   'love',
#   'stay',
#   'christopher',
#   'robin',
#   'go',
#   'zoo',
#   'go',
#   'polar',
#   'bear',
#   'whisper',
#   'something',
#   'third',
#   'keeper',
#   'left',
#   'door',
#   'unlocked',
#   'wander',
#   'dark',
#   'passage',
#   'steep',
#   'stair',
#   'last',
#   'come',
#   'special',
#   'cage',
#   'cage',
#   'opened',
#   'trot',
#   'something',
#   'brown',
#   'furry',
#   'happy',
#   'cry',
#   'oh',
#   'bear',
#   'christopher',
#   'robin',
#   'rush',
#   'arm',
#   'bear',
#   'name',
#   'winnie',
#   'show',
#   'good',
#   'name',
#   'bear',
#   'funny',
#   'thing',
#   'cant',
#   'remember',
#   'whether',
#   'winnie',
#   'called',
#   'pooh',
#   'pooh',
#   'winnie',
#   'know',
#   'forgotten',
#   'written',
#   'far',
#   'piglet',
#   'looked',
#   'said',
#   'squeaky',
#   'voice',
#   'dear',
#   'piglet',
#   'said',
#   'whole',
#   'book',
#   'pooh',
#   'squeaked',
#   'see',
#   'jealous',
#   'think',
#   'pooh',
#   'grand',
#   'introduction',
#   'pooh',
#   'favourite',
#   'course',
#   'there',
#   'denying',
#   'piglet',
#   'come',
#   'good',
#   'many',
#   'thing',
#   'pooh',
#   'miss',
#   'cant',
#   'take',
#   'pooh',
#   'school',
#   'without',
#   'everybody',
#   'knowing',
#   'piglet',
#   'small',
#   'slip',
#   'pocket',
#   'comforting',
#   'feel',
#   'quite',
#   'sure',
#   'whether',
#   'twice',
#   'seven',
#   'twelve',
#   'twentytwo',
#   'sometimes',
#   'slip',
#   'good',
#   'look',
#   'inkpot',
#   'way',
#   'got',
#   'education',
#   'pooh',
#   'pooh',
#   'doesnt',
#   'mind',
#   'brain',
#   'havent',
#   'say',
#   'others',
#   'saying',
#   'u',
#   'perhaps',
#   'best',
#   'thing',
#   'stop',
#   'writing',
#   'introduction',
#   'get',
#   'book',
#   'content',
#   'introduced',
#   'winniethepooh',
#   'bee',
#   'story',
#   'begin',
#   'ii',
#   'pooh',
#   'go',
#   'visiting',
#   'get',
#   'tight',
#   'place',
#   'iii',
#   'pooh',
#   'piglet',
#   'go',
#   'hunting',
#   'nearly',
#   'catch',
#   'woozle',
#   'iv',
#   'eeyore',
#   'loses',
#   'tail',
#   'pooh',
#   'find',
#   'one',
#   'v',
#   'piglet',
#   'meet',
#   'heffalump',
#   'vi',
#   'eeyore',
#   'birthday',
#   'get',
#   'two',
#   'present',
#   'vii',
#   'kanga',
#   'baby',
#   'roo',
#   'come',
#   'forest',
#   'piglet',
#   'bath',
#   'viii',
#   'christopher',
#   'robin',
#   'lead',
#   'expotition',
#   'north',
#   'pole',
#   'ix',
#   'piglet',
#   'entirely',
#   'surrounded',
#   'water',
#   'x',
#   'christopher',
#   'robin',
#   'give',
#   'pooh',
#   'party',
#   'say',
#   'goodbye',
#   'winniethepooh',
#   'chapter',
#   'introduced',
#   'winniethepooh',
#   'bee',
#   'story',
#   'begin',
#   'edward',
#   'bear',
#   'coming',
#   'downstairs',
#   'bump',
#   'bump',
#   'bump',
#   'back',
#   'head',
#   'behind',
#   'christopher',
#   'robin',
#   'far',
#   'know',
#   'way',
#   'coming',
#   'downstairs',
#   'sometimes',
#   'feel',
#   'really',
#   'another',
#   'way',
#   'could',
#   'stop',
#   'bumping',
#   'moment',
#   'think',
#   'feel',
#   'perhaps',
#   'isnt',
#   'anyhow',
#   'bottom',
#   'ready',
#   'introduced',
#   'winniethepooh',
#   'first',
#   'heard',
#   'name',
#   'said',
#   'going',
#   'say',
#   'thought',
#   'boy',
#   'said',
#   'christopher',
#   'robin',
#   'cant',
#   'call',
#   'winnie',
#   'dont',
#   'said',
#   'he',
#   'winnietherpooh',
#   'dont',
#   'know',
#   'ther',
#   'mean',
#   'ah',
#   'yes',
#   'said',
#   'quickly',
#   'hope',
#   'explanation',
#   'going',
#   'get',
#   'sometimes',
#   'winniethepooh',
#   'like',
#   'game',
#   'sort',
#   'come',
#   'downstairs',
#   'sometimes',
#   'like',
#   'sit',
#   'quietly',
#   'front',
#   'fire',
#   'listen',
#   'story',
#   'evening',
#   'story',
#   'said',
#   'christopher',
#   'robin',
#   'story',
#   'said',
#   'could',
#   'sweetly',
#   'tell',
#   'winniethepooh',
#   'one',
#   'suppose',
#   'could',
#   'said',
#   'sort',
#   'story',
#   'like',
#   'he',
#   'sort',
#   'bear',
#   'oh',
#   'see',
#   'could',
#   'sweetly',
#   'ill',
#   'try',
#   'said',
#   'tried',
#   'upon',
#   'time',
#   'long',
#   'time',
#   'ago',
#   'last',
#   'friday',
#   'winniethepooh',
#   'lived',
#   'forest',
#   'name',
#   'sander',
#   'name',
#   'mean',
#   'asked',
#   'christopher',
#   'robin',
#   'mean',
#   'name',
#   'door',
#   'gold',
#   'letter',
#   'lived',
#   'winniethepooh',
#   'wasnt',
#   'quite',
#   'sure',
#   'said',
#   'christopher',
#   'robin',
#   'said',
#   'growly',
#   'voice',
#   'go',
#   'said',
#   'one',
#   'day',
#   'walking',
#   'came',
#   'open',
#   'place',
#   'middle',
#   'forest',
#   'middle',
#   'place',
#   'large',
#   'oaktree',
#   'top',
#   'tree',
#   'came',
#   'loud',
#   'buzzingnoise',
#   'winniethepooh',
#   'sat',
#   'foot',
#   'tree',
#   'put',
#   'head',
#   'paw',
#   'began',
#   'think',
#   'first',
#   'said',
#   'buzzingnoise',
#   'mean',
#   'something',
#   'dont',
#   'get',
#   'buzzingnoise',
#   'like',
#   'buzzing',
#   'buzzing',
#   'without',
#   'meaning',
#   'something',
#   'there',
#   'buzzingnoise',
#   'somebody',
#   'making',
#   'buzzingnoise',
#   'reason',
#   'making',
#   'buzzingnoise',
#   'know',
#   'youre',
#   'bee',
#   'thought',
#   'another',
#   'long',
#   'time',
#   'said',
#   'reason',
#   'bee',
#   'know',
#   'making',
#   'honey',
#   'got',
#   'said',
#   'reason',
#   'making',
#   'honey',
#   'eat',
#   'began',
#   'climb',
#   'tree',
#   'climbed',
#   'climbed',
#   'climbed',
#   'climbed',
#   'sang',
#   'little',
#   'song',
#   'went',
#   'like',
#   'isnt',
#   'funny',
#   'bear',
#   'like',
#   'honey',
#   'buzz',
#   'buzz',
#   'buzz',
#   'wonder',
#   'climbed',
#   'little',
#   'little',
#   'little',
#   'time',
#   'thought',
#   'another',
#   'song',
#   'funny',
#   'thought',
#   'bear',
#   'bee',
#   'theyd',
#   'build',
#   'nest',
#   'bottom',
#   'tree',
#   'bee',
#   'bear',
#   'shouldnt',
#   'climb',
#   'stair',
#   'getting',
#   'rather',
#   'tired',
#   'time',
#   'sang',
#   'complaining',
#   'song',
#   'nearly',
#   'stood',
#   'branch',
#   'crack',
#   'oh',
#   'help',
#   'said',
#   'pooh',
#   'dropped',
#   'ten',
#   'foot',
#   'branch',
#   'hadnt',
#   'said',
#   'bounced',
#   'twenty',
#   'foot',
#   'next',
#   'branch',
#   'see',
#   'meant',
#   'explained',
#   'turned',
#   'headoverheels',
#   'crashed',
#   'another',
#   'branch',
#   'thirty',
#   'foot',
#   'meant',
#   'course',
#   'rather',
#   'admitted',
#   'slithered',
#   'quickly',
#   'next',
#   'six',
#   'branch',
#   'come',
#   'suppose',
#   'decided',
#   'said',
#   'goodbye',
#   'last',
#   'branch',
#   'spun',
#   'round',
#   'three',
#   'time',
#   'flew',
#   'gracefully',
#   'gorsebush',
#   'come',
#   'liking',
#   'honey',
#   'much',
#   'oh',
#   'help',
#   'crawled',
#   'gorsebush',
#   'brushed',
#   'prickle',
#   'nose',
#   'began',
#   'think',
#   'first',
#   'person',
#   'thought',
#   'christopher',
#   'robin',
#   'said',
#   'christopher',
#   'robin',
#   'awed',
#   'voice',
#   'hardly',
#   'daring',
#   'believe',
#   'christopher',
#   'robin',
#   'said',
#   'nothing',
#   'eye',
#   'got',
#   'larger',
#   'larger',
#   'face',
#   'got',
#   'pinker',
#   'pinker',
#   'winniethepooh',
#   'went',
#   'round',
#   'friend',
#   'christopher',
#   'robin',
#   'lived',
#   'behind',
#   'green',
#   'door',
#   'another',
#   'part',
#   'forest',
#   'good',
#   'morning',
#   'christopher',
#   'robin',
#   'said',
#   'good',
#   'morning',
#   'winnietherpooh',
#   'said',
#   'wonder',
#   'youve',
#   'got',
#   'thing',
#   'balloon',
#   'balloon',
#   'yes',
#   'said',
#   'coming',
#   'along',
#   'wonder',
#   'christopher',
#   'robin',
#   'thing',
#   'balloon',
#   'said',
#   'thinking',
#   'balloon',
#   'wondering',
#   'want',
#   'balloon',
#   'said',
#   'winniethepooh',
#   'looked',
#   'round',
#   'see',
#   'nobody',
#   'listening',
#   'put',
#   'paw',
#   'mouth',
#   'said',
#   'deep',
#   'whisper',
#   'honey',
#   'dont',
#   'get',
#   'honey',
#   'balloon',
#   'said',
#   'pooh',
#   'well',
#   'happened',
#   'party',
#   'day',
#   'house',
#   'friend',
#   'piglet',
#   'balloon',
#   'party',
#   'big',
#   'green',
#   'balloon',
#   'one',
#   'rabbit',
#   'relation',
#   'big',
#   'blue',
#   'one',
#   'left',
#   'behind',
#   'really',
#   'young',
#   'go',
#   'party',
#   'brought',
#   'green',
#   'one',
#   'blue',
#   'one',
#   'home',
#   'one',
#   'would',
#   'like',
#   'asked',
#   'pooh',
#   'put',
#   'head',
#   'paw',
#   'thought',
#   'carefully',
#   'like',
#   'said',
#   'go',
#   'honey',
#   'balloon',
#   'great',
#   'thing',
#   'let',
#   'bee',
#   'know',
#   'youre',
#   'coming',
#   'green',
#   'balloon',
#   'might',
#   'think',
#   'part',
#   'tree',
#   'notice',
#   'blue',
#   'balloon',
#   'might',
#   'think',
#   'part',
#   'sky',
#   'notice',
#   'question',
#   'likely',
#   'wouldnt',
#   'notice',
#   'underneath',
#   'balloon',
#   'asked',
#   'might',
#   'might',
#   'said',
#   'winniethepooh',
#   'never',
#   'tell',
#   'bee',
#   'thought',
#   'moment',
#   'said',
#   'shall',
#   'try',
#   'look',
#   'like',
#   'small',
#   'black',
#   'cloud',
#   'deceive',
#   'better',
#   'blue',
#   'balloon',
#   'said',
#   'decided',
#   'well',
#   'went',
#   'blue',
#   'balloon',
#   'took',
#   'gun',
#   'case',
#   'always',
#   'winniethepooh',
#   'went',
#   'muddy',
#   'place',
#   'knew',
#   'rolled',
#   'rolled',
#   'black',
#   'balloon',
#   'blown',
#   'big',
#   'big',
#   'pooh',
#   'holding',
#   'string',
#   'let',
#   'go',
#   'suddenly',
#   'pooh',
#   'bear',
#   'floated',
#   'gracefully',
#   'sky',
#   'stayed',
#   ...]]

# %%
doc_tfidf_vectors = [compute_tfidf(doc, preprocessed_docs, vocab) for doc in preprocessed_docs]

# %%
doc_tfidf_vectors
# Out:
# [array([0.00000000e+00, 2.44415890e-05, 9.77663562e-05, ...,
#         2.44415890e-05, 0.00000000e+00, 0.00000000e+00]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  array([0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.00011388]),
#  array([7.21716077e-05, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 2.16514823e-04, 0.00000000e+00])]

# %%
queries = ["winniethepooh went", "big sky","Enter Sampson and Gregory armed with swords and bucklers","There is a delicious garden!"]

tokenized_queries = [preprocess(query) for query in queries]

query_tfidf_vectors = [compute_tfidf(query, preprocessed_docs, vocab) for query in tokenized_queries]

# for i, vec in enumerate(query_tfidf_vectors):
#     print(f"TF-IDF Vector for Query '{queries[i]}': {vec}")

# %%
def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

# %%
cosine_similarities = []
for query_vector in query_tfidf_vectors:
    similarities = [cosine_similarity(query_vector, doc_vector) for doc_vector in doc_tfidf_vectors]
    cosine_similarities.append(similarities)

# %%
cosine_similarities
# Out:
# [[0.004716332320102101,
#   0.0012944850630437184,
#   0.004603374290445432,
#   7.779144281496628e-05,
#   0.12637618059719216],
#  [0.0035486074671462536,
#   0.008393891419000333,
#   0.0019383919940400278,
#   0.0005044267739798153,
#   0.009328321063254322],
#  [0.0008394896061305753, 0.0, 7.659646362403322e-05, 0.04701385166774868, 0.0],
#  [0.0010563782802165556,
#   0.0040591971400530035,
#   0.0011548069135959456,
#   0.0,
#   0.0]]

# %%
cosine_similarities = []
for query_vector in query_tfidf_vectors:
    similarities = [cosine_similarity(query_vector, doc_vector) for doc_vector in doc_tfidf_vectors]
    cosine_similarities.append(similarities)

for i, query in enumerate(queries):
    print(f"\nCosine similarities for query '{query}':")
    if i < len(cosine_similarities):
        for j, doc in enumerate(doc_files):
            if j < len(cosine_similarities[i]):
                print(f"Document {j + 1}: {cosine_similarities[i][j]:.4f}")
            else:
                print(f"Document {j + 1}: No similarity calculated")
    else:
        print("No similarities calculated for this query.")
# Out:
# Cosine similarities for query 'winniethepooh went':
# Document 1: 0.0047
# Document 2: 0.0013
# Document 3: 0.0046
# Document 4: 0.0001
# Document 5: 0.1264
#
# Cosine similarities for query 'big sky':
# Document 1: 0.0035
# Document 2: 0.0084
# Document 3: 0.0019
# Document 4: 0.0005
# Document 5: 0.0093
#
# Cosine similarities for query 'Enter Sampson and Gregory armed with swords and bucklers':
# Document 1: 0.0008
# Document 2: 0.0000
# Document 3: 0.0001
# Document 4: 0.0470
# Document 5: 0.0000
#
# Cosine similarities for query 'There is a delicious garden!':
# Document 1: 0.0011
# Document 2: 0.0041
# Document 3: 0.0012
# Document 4: 0.0000
# Document 5: 0.0000

# %%
for i, query in enumerate(queries):
    print(f"\nCosine similarities for query '{query}':")
    for j, doc in enumerate(doc_files):
        print(f"Document {j + 1}: {cosine_similarities[i][j]:.4f}")
# Out:
# Cosine similarities for query 'winniethepooh went':
# Document 1: 0.0047
# Document 2: 0.0013
# Document 3: 0.0046
# Document 4: 0.0001
# Document 5: 0.1264
#
# Cosine similarities for query 'big sky':
# Document 1: 0.0035
# Document 2: 0.0084
# Document 3: 0.0019
# Document 4: 0.0005
# Document 5: 0.0093
#
# Cosine similarities for query 'Enter Sampson and Gregory armed with swords and bucklers':
# Document 1: 0.0008
# Document 2: 0.0000
# Document 3: 0.0001
# Document 4: 0.0470
# Document 5: 0.0000
#
# Cosine similarities for query 'There is a delicious garden!':
# Document 1: 0.0011
# Document 2: 0.0041
# Document 3: 0.0012
# Document 4: 0.0000
# Document 5: 0.0000

# %%
# output_file = 'Kshitiz_Shah'
# with open(output_file, 'w') as w:
#     w.write(f"\nCosine similarities for query '{query}':")
#     for j, doc in enumerate(doc_files):
#         w.write(f"Document {j + 1}: {cosine_similarities[i][j]:.4f}")
